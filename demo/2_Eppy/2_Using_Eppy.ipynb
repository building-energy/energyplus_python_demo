# %% [markdown]
# # 2_Using_Eppy

# %% [markdown]
# ## Intro
#
# Eppy can be used to modify EnergyPlus idf files.
#
# It's open source and can be viewed here: https://github.com/santoshphilip/eppy
#
# This demo uses the following idf file, which is available in the ExampleFiles in the EnergyPlus installation.

# %%
with open('1ZoneUncontrolled.idf','r') as f:
    print(f.read())
# Out:
# !-Generator IDFEditor 1.34
# !-Option OriginalOrderTop UseSpecialFormat
# !-NOTE: All comments with '!-' are ignored by the IDFEditor and are generated automatically.
# !-      Use '!' comments if they need to be retained when using the IDFEditor.
# !1ZoneUncontrolled.idf
# ! Basic file description:  Basic test for EnergyPlus.  Resistive Walls.  Regular (no ground contact) floor.
# !                          Regular roof.  No Windows.
# !
# ! Highlights:              Very basic test to see that EnergyPlus "works".
# !
# !
# ! Simulation Location/Run: Denver Centennial  Golden CO USA WMO=724666, 2 design days, 1 run period,
# !                          Run Control executes two design days (see RUN PERIOD object)
# !
# ! Location:                Denver, CO
# !
# ! Design Days:             Denver Centennial  Golden CO USA Annual Heating 99%, MaxDB=-15.5Â°C
# !                          Denver Centennial  Golden CO USA Annual Cooling (DB=>MWB) 1%, MaxDB=32Â°C MWB=15.5Â°C
# !
# ! Run Period (Weather File): Full Annual Simulation, DENVER_STAPLETON_CO_USA_WMO_724690
# !
# ! Run Control:             No zone or system sizing, design day run control (no weather file simulation)
# !
# ! Building: Fictional 1 zone building with resistive walls.
# !
# !           The building is oriented due north.
# !
# ! Floor Area:        232.25 m2
# ! Number of Stories: 1
# !
# ! Zone Description Details:
# !
# !       (0,15.24,0)                 (15.24,15.24,0)
# !              _____________________________
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |                             |
# !             |_____________________________|
# !
# !          (0,0,0)                      (15.24,0,0)
# !
# ! Internal gains description:     NA
# !
# ! Interzone Surfaces:             None
# ! Internal Mass:                  None
# ! People:                         None
# ! Lights:                         None
# ! Equipment:                      None
# ! Windows:                        0
# ! Detached Shading:               None
# ! Daylight:                       None
# ! Natural Ventilation:            None
# ! Compact Schedules:              NA (Example of non-Compact Schedules)
# ! Solar Distribution:             MinimalShadowing
# !
# ! HVAC:                           NA
# !
# ! Zonal Equipment:                NA
# ! Central Air Handling Equipment: No
# ! System Equipment Autosize:      No
# ! Purchased Cooling:              No
# ! Purchased Heating:              No
# ! Purchased Chilled Water:        No
# ! Purchased Hot Water:            No
# ! Coils:                          None
# ! Pumps:                          None
# ! Boilers:                        None
# ! Chillers:                       None
# ! Towers:                         None
# !
# ! Results:
# ! Standard Reports:               Variable Dictionary, Surfaces (dxf-wireframe), Meter File
# ! Timestep or Hourly Variables:   Hourly and Daily
# ! Time bins Report:               None
# ! HTML Report:                    None
# ! Environmental Emissions:        None
# ! Utility Tariffs:                None
#
#   Version,8.9;
#
#   Timestep,4;
#
#   Building,
#     Simple One Zone (Wireframe DXF),  !- Name
#     0,                       !- North Axis {deg}
#     Suburbs,                 !- Terrain
#     0.04,                    !- Loads Convergence Tolerance Value
#     0.004,                   !- Temperature Convergence Tolerance Value {deltaC}
#     MinimalShadowing,        !- Solar Distribution
#     30,                      !- Maximum Number of Warmup Days
#     6;                       !- Minimum Number of Warmup Days
#
#   HeatBalanceAlgorithm,ConductionTransferFunction;
#
#   SurfaceConvectionAlgorithm:Inside,TARP;
#
#   SurfaceConvectionAlgorithm:Outside,DOE-2;
#
#   SimulationControl,
#     No,                      !- Do Zone Sizing Calculation
#     No,                      !- Do System Sizing Calculation
#     No,                      !- Do Plant Sizing Calculation
#     Yes,                     !- Run Simulation for Sizing Periods
#     Yes;                     !- Run Simulation for Weather File Run Periods
#
#   RunPeriod,
#     ,                        !- Name
#     1,                       !- Begin Month
#     1,                       !- Begin Day of Month
#     12,                      !- End Month
#     31,                      !- End Day of Month
#     Tuesday,                 !- Day of Week for Start Day
#     Yes,                     !- Use Weather File Holidays and Special Days
#     Yes,                     !- Use Weather File Daylight Saving Period
#     No,                      !- Apply Weekend Holiday Rule
#     Yes,                     !- Use Weather File Rain Indicators
#     Yes;                     !- Use Weather File Snow Indicators
#
#   Site:Location,
#     Denver Centennial  Golden   N_CO_USA Design_Conditions,  !- Name
#     39.74,                   !- Latitude {deg}
#     -105.18,                 !- Longitude {deg}
#     -7.00,                   !- Time Zone {hr}
#     1829.00;                 !- Elevation {m}
#
#  !  WMO=724666 Time Zone=NAM: (GMT-07:00) Mountain Time (US & Canada)
#  !  Data Source=ASHRAE 2009 Annual Design Conditions
#  ! Denver Centennial  Golden   N_CO_USA Annual Heating Design Conditions Wind Speed=3m/s Wind Dir=340
#  ! Coldest Month=DEC
#  ! Denver Centennial  Golden   N_CO_USA Annual Heating 99%, MaxDB=-15.5Â°C
#
#   SizingPeriod:DesignDay,
#     Denver Centennial  Golden   N Ann Htg 99% Condns DB,  !- Name
#     12,                      !- Month
#     21,                      !- Day of Month
#     WinterDesignDay,         !- Day Type
#     -15.5,                   !- Maximum Dry-Bulb Temperature {C}
#     0.0,                     !- Daily Dry-Bulb Temperature Range {deltaC}
#     ,                        !- Dry-Bulb Temperature Range Modifier Type
#     ,                        !- Dry-Bulb Temperature Range Modifier Day Schedule Name
#     Wetbulb,                 !- Humidity Condition Type
#     -15.5,                   !- Wetbulb or DewPoint at Maximum Dry-Bulb {C}
#     ,                        !- Humidity Condition Day Schedule Name
#     ,                        !- Humidity Ratio at Maximum Dry-Bulb {kgWater/kgDryAir}
#     ,                        !- Enthalpy at Maximum Dry-Bulb {J/kg}
#     ,                        !- Daily Wet-Bulb Temperature Range {deltaC}
#     81198.,                  !- Barometric Pressure {Pa}
#     3,                       !- Wind Speed {m/s}
#     340,                     !- Wind Direction {deg}
#     No,                      !- Rain Indicator
#     No,                      !- Snow Indicator
#     No,                      !- Daylight Saving Time Indicator
#     ASHRAEClearSky,          !- Solar Model Indicator
#     ,                        !- Beam Solar Day Schedule Name
#     ,                        !- Diffuse Solar Day Schedule Name
#     ,                        !- ASHRAE Clear Sky Optical Depth for Beam Irradiance (taub) {dimensionless}
#     ,                        !- ASHRAE Clear Sky Optical Depth for Diffuse Irradiance (taud) {dimensionless}
#     0.00;                    !- Sky Clearness
#
#  ! Denver Centennial  Golden   N Annual Cooling Design Conditions Wind Speed=4.9m/s Wind Dir=0
#  ! Hottest Month=JUL
#  ! Denver Centennial  Golden   N_CO_USA Annual Cooling (DB=>MWB) 1%, MaxDB=32Â°C MWB=15.5Â°C
#
#   SizingPeriod:DesignDay,
#     Denver Centennial  Golden   N Ann Clg 1% Condns DB=>MWB,  !- Name
#     7,                       !- Month
#     21,                      !- Day of Month
#     SummerDesignDay,         !- Day Type
#     32,                      !- Maximum Dry-Bulb Temperature {C}
#     15.2,                    !- Daily Dry-Bulb Temperature Range {deltaC}
#     ,                        !- Dry-Bulb Temperature Range Modifier Type
#     ,                        !- Dry-Bulb Temperature Range Modifier Day Schedule Name
#     Wetbulb,                 !- Humidity Condition Type
#     15.5,                    !- Wetbulb or DewPoint at Maximum Dry-Bulb {C}
#     ,                        !- Humidity Condition Day Schedule Name
#     ,                        !- Humidity Ratio at Maximum Dry-Bulb {kgWater/kgDryAir}
#     ,                        !- Enthalpy at Maximum Dry-Bulb {J/kg}
#     ,                        !- Daily Wet-Bulb Temperature Range {deltaC}
#     81198.,                  !- Barometric Pressure {Pa}
#     4.9,                     !- Wind Speed {m/s}
#     0,                       !- Wind Direction {deg}
#     No,                      !- Rain Indicator
#     No,                      !- Snow Indicator
#     No,                      !- Daylight Saving Time Indicator
#     ASHRAEClearSky,          !- Solar Model Indicator
#     ,                        !- Beam Solar Day Schedule Name
#     ,                        !- Diffuse Solar Day Schedule Name
#     ,                        !- ASHRAE Clear Sky Optical Depth for Beam Irradiance (taub) {dimensionless}
#     ,                        !- ASHRAE Clear Sky Optical Depth for Diffuse Irradiance (taud) {dimensionless}
#     1.00;                    !- Sky Clearness
#
#   Material:NoMass,
#     R13LAYER,                !- Name
#     Rough,                   !- Roughness
#     2.290965,                !- Thermal Resistance {m2-K/W}
#     0.9000000,               !- Thermal Absorptance
#     0.7500000,               !- Solar Absorptance
#     0.7500000;               !- Visible Absorptance
#
#   Material:NoMass,
#     R31LAYER,                !- Name
#     Rough,                   !- Roughness
#     5.456,                   !- Thermal Resistance {m2-K/W}
#     0.9000000,               !- Thermal Absorptance
#     0.7500000,               !- Solar Absorptance
#     0.7500000;               !- Visible Absorptance
#
#   Material,
#     C5 - 4 IN HW CONCRETE,   !- Name
#     MediumRough,             !- Roughness
#     0.1014984,               !- Thickness {m}
#     1.729577,                !- Conductivity {W/m-K}
#     2242.585,                !- Density {kg/m3}
#     836.8000,                !- Specific Heat {J/kg-K}
#     0.9000000,               !- Thermal Absorptance
#     0.6500000,               !- Solar Absorptance
#     0.6500000;               !- Visible Absorptance
#
#   Construction,
#     R13WALL,                 !- Name
#     R13LAYER;                !- Outside Layer
#
#   Construction,
#     FLOOR,                   !- Name
#     C5 - 4 IN HW CONCRETE;   !- Outside Layer
#
#   Construction,
#     ROOF31,                  !- Name
#     R31LAYER;                !- Outside Layer
#
#   Zone,
#     ZONE ONE,                !- Name
#     0,                       !- Direction of Relative North {deg}
#     0,                       !- X Origin {m}
#     0,                       !- Y Origin {m}
#     0,                       !- Z Origin {m}
#     1,                       !- Type
#     1,                       !- Multiplier
#     autocalculate,           !- Ceiling Height {m}
#     autocalculate;           !- Volume {m3}
#
#   ScheduleTypeLimits,
#     Fraction,                !- Name
#     0.0,                     !- Lower Limit Value
#     1.0,                     !- Upper Limit Value
#     CONTINUOUS;              !- Numeric Type
#
#   GlobalGeometryRules,
#     UpperLeftCorner,         !- Starting Vertex Position
#     CounterClockWise,        !- Vertex Entry Direction
#     World;                   !- Coordinate System
#
#   BuildingSurface:Detailed,
#     Zn001:Wall001,           !- Name
#     Wall,                    !- Surface Type
#     R13WALL,                 !- Construction Name
#     ZONE ONE,                !- Zone Name
#     Outdoors,                !- Outside Boundary Condition
#     ,                        !- Outside Boundary Condition Object
#     SunExposed,              !- Sun Exposure
#     WindExposed,             !- Wind Exposure
#     0.5000000,               !- View Factor to Ground
#     4,                       !- Number of Vertices
#     0,0,4.572000,  !- X,Y,Z ==> Vertex 1 {m}
#     0,0,0,  !- X,Y,Z ==> Vertex 2 {m}
#     15.24000,0,0,  !- X,Y,Z ==> Vertex 3 {m}
#     15.24000,0,4.572000;  !- X,Y,Z ==> Vertex 4 {m}
#
#   BuildingSurface:Detailed,
#     Zn001:Wall002,           !- Name
#     Wall,                    !- Surface Type
#     R13WALL,                 !- Construction Name
#     ZONE ONE,                !- Zone Name
#     Outdoors,                !- Outside Boundary Condition
#     ,                        !- Outside Boundary Condition Object
#     SunExposed,              !- Sun Exposure
#     WindExposed,             !- Wind Exposure
#     0.5000000,               !- View Factor to Ground
#     4,                       !- Number of Vertices
#     15.24000,0,4.572000,  !- X,Y,Z ==> Vertex 1 {m}
#     15.24000,0,0,  !- X,Y,Z ==> Vertex 2 {m}
#     15.24000,15.24000,0,  !- X,Y,Z ==> Vertex 3 {m}
#     15.24000,15.24000,4.572000;  !- X,Y,Z ==> Vertex 4 {m}
#
#   BuildingSurface:Detailed,
#     Zn001:Wall003,           !- Name
#     Wall,                    !- Surface Type
#     R13WALL,                 !- Construction Name
#     ZONE ONE,                !- Zone Name
#     Outdoors,                !- Outside Boundary Condition
#     ,                        !- Outside Boundary Condition Object
#     SunExposed,              !- Sun Exposure
#     WindExposed,             !- Wind Exposure
#     0.5000000,               !- View Factor to Ground
#     4,                       !- Number of Vertices
#     15.24000,15.24000,4.572000,  !- X,Y,Z ==> Vertex 1 {m}
#     15.24000,15.24000,0,  !- X,Y,Z ==> Vertex 2 {m}
#     0,15.24000,0,  !- X,Y,Z ==> Vertex 3 {m}
#     0,15.24000,4.572000;  !- X,Y,Z ==> Vertex 4 {m}
#
#   BuildingSurface:Detailed,
#     Zn001:Wall004,           !- Name
#     Wall,                    !- Surface Type
#     R13WALL,                 !- Construction Name
#     ZONE ONE,                !- Zone Name
#     Outdoors,                !- Outside Boundary Condition
#     ,                        !- Outside Boundary Condition Object
#     SunExposed,              !- Sun Exposure
#     WindExposed,             !- Wind Exposure
#     0.5000000,               !- View Factor to Ground
#     4,                       !- Number of Vertices
#     0,15.24000,4.572000,  !- X,Y,Z ==> Vertex 1 {m}
#     0,15.24000,0,  !- X,Y,Z ==> Vertex 2 {m}
#     0,0,0,  !- X,Y,Z ==> Vertex 3 {m}
#     0,0,4.572000;  !- X,Y,Z ==> Vertex 4 {m}
#
#   BuildingSurface:Detailed,
#     Zn001:Flr001,            !- Name
#     Floor,                   !- Surface Type
#     FLOOR,                   !- Construction Name
#     ZONE ONE,                !- Zone Name
#     Adiabatic,               !- Outside Boundary Condition
#     ,                        !- Outside Boundary Condition Object
#     NoSun,                   !- Sun Exposure
#     NoWind,                  !- Wind Exposure
#     1.000000,                !- View Factor to Ground
#     4,                       !- Number of Vertices
#     15.24000,0.000000,0.0,  !- X,Y,Z ==> Vertex 1 {m}
#     0.000000,0.000000,0.0,  !- X,Y,Z ==> Vertex 2 {m}
#     0.000000,15.24000,0.0,  !- X,Y,Z ==> Vertex 3 {m}
#     15.24000,15.24000,0.0;  !- X,Y,Z ==> Vertex 4 {m}
#
#   BuildingSurface:Detailed,
#     Zn001:Roof001,           !- Name
#     Roof,                    !- Surface Type
#     ROOF31,                  !- Construction Name
#     ZONE ONE,                !- Zone Name
#     Outdoors,                !- Outside Boundary Condition
#     ,                        !- Outside Boundary Condition Object
#     SunExposed,              !- Sun Exposure
#     WindExposed,             !- Wind Exposure
#     0,                       !- View Factor to Ground
#     4,                       !- Number of Vertices
#     0.000000,15.24000,4.572,  !- X,Y,Z ==> Vertex 1 {m}
#     0.000000,0.000000,4.572,  !- X,Y,Z ==> Vertex 2 {m}
#     15.24000,0.000000,4.572,  !- X,Y,Z ==> Vertex 3 {m}
#     15.24000,15.24000,4.572;  !- X,Y,Z ==> Vertex 4 {m}
#
#   Output:Variable,*,Site Outdoor Air Drybulb Temperature,hourly;
#
#   Output:Variable,*,Site Daylight Saving Time Status,daily;
#
#   Output:Variable,*,Site Day Type Index,daily;
#
#   Output:Variable,*,Zone Mean Air Temperature,hourly;
#
#   Output:Variable,*,Zone Total Internal Latent Gain Energy,hourly;
#
#   Output:Variable,*,Zone Mean Radiant Temperature,hourly;
#
#   Output:Variable,*,Zone Air Heat Balance Surface Convection Rate,hourly;
#
#   Output:Variable,*,Zone Air Heat Balance Air Energy Storage Rate,hourly;
#
#   Output:Variable,*,Surface Inside Face Temperature,daily;
#
#   Output:Variable,*,Surface Outside Face Temperature,daily;
#
#   Output:Variable,*,Surface Inside Face Convection Heat Transfer Coefficient,daily;
#
#   Output:Variable,*,Surface Outside Face Convection Heat Transfer Coefficient,daily;
#
#   Output:Variable,*,Other Equipment Total Heating Energy,monthly;
#
#   Output:Variable,*,Zone Other Equipment Total Heating Energy,monthly;
#
#   Output:VariableDictionary,IDF;
#
#   Output:Surfaces:Drawing,dxf:wireframe;
#
#   Output:Constructions,Constructions;
#
#   Output:Meter:MeterFileOnly,ExteriorLights:Electricity,hourly;
#
#   Output:Meter:MeterFileOnly,EnergyTransfer:Building,hourly;
#
#   Output:Meter:MeterFileOnly,EnergyTransfer:Facility,hourly;
#
#   OutputControl:Table:Style,
#     ALL;                     !- Column Separator
#
#   Output:Table:SummaryReports,
#     AllSummary;              !- Report 1 Name
#
#   Exterior:Lights,
#     ExtLights,               !- Name
#     AlwaysOn,                !- Schedule Name
#     5250,                    !- Design Level {W}
#     AstronomicalClock,       !- Control Option
#     Grounds Lights;          !- End-Use Subcategory
#
#   ScheduleTypeLimits,
#     On/Off,                  !- Name
#     0,                       !- Lower Limit Value
#     1,                       !- Upper Limit Value
#     DISCRETE;                !- Numeric Type
#
#   OtherEquipment,
#     Test 352a,               !- Name
#     None,                    !- Fuel Type
#     ZONE ONE,                !- Zone or ZoneList Name
#     AlwaysOn,                !- Schedule Name
#     EquipmentLevel,          !- Design Level Calculation Method
#     352,                     !- Design Level {W}
#     ,                        !- Power per Zone Floor Area {W/m2}
#     ,                        !- Power per Person {W/person}
#     0,                       !- Fraction Latent
#     0,                       !- Fraction Radiant
#     0;                       !- Fraction Lost
#
#   OtherEquipment,
#     Test 352 minus,          !- Name
#     None,                    !- Fuel Type
#     ZONE ONE,                !- Zone or ZoneList Name
#     AlwaysOn,                !- Schedule Name
#     EquipmentLevel,          !- Design Level Calculation Method
#     -352,                    !- Design Level {W}
#     ,                        !- Power per Zone Floor Area {W/m2}
#     ,                        !- Power per Person {W/person}
#     0,                       !- Fraction Latent
#     0,                       !- Fraction Radiant
#     0;                       !- Fraction Lost
#
#   Schedule:Constant,AlwaysOn,On/Off,1.0;

# %% [markdown]
# ## Setting up Eppy

# %% [markdown]
# ### Install Eppy if it isn't already available

# %%
# !pip install eppy
# Out:
# Requirement already satisfied: eppy in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (0.5.46)
# Requirement already satisfied: pytest>=3.2.1 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from eppy) (3.5.0)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from eppy) (4.3.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from eppy) (1.11.0)
# Requirement already satisfied: beautifulsoup4>=4.2.1 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from eppy) (4.6.0)
# Requirement already satisfied: tinynumpy>=1.2.1 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from eppy) (1.2.1)
# Requirement already satisfied: lxml>=3.8.0 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from eppy) (4.2.1)
# Requirement already satisfied: pydot3k; python_version >= "3.0" in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from eppy) (1.0.17)
# Requirement already satisfied: munch>=2.0.2 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from eppy) (2.1.1)
# Requirement already satisfied: py>=1.5.0 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from pytest>=3.2.1->eppy) (1.5.3)
# Requirement already satisfied: setuptools in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from pytest>=3.2.1->eppy) (39.1.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from pytest>=3.2.1->eppy) (17.4.0)
# Requirement already satisfied: more_itertools>=4.0.0 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from pytest>=3.2.1->eppy) (4.1.0)
# Requirement already satisfied: pluggy<0.7,>=0.5 in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from pytest>=3.2.1->eppy) (0.6.0)
# Requirement already satisfied: colorama in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from pytest>=3.2.1->eppy) (0.3.9)
# Requirement already satisfied: pyparsing in c:\users\cvskf\appdata\local\continuum\anaconda3\lib\site-packages (from pydot3k; python_version >= "3.0"->eppy) (2.2.0)

# %% [markdown]
# ### Import IDF class

# %%
from eppy.modeleditor import IDF
IDF
# Out:
# eppy.modeleditor.IDF

# %%
help(IDF)
# Out:
# Help on class IDF in module eppy.modeleditor:
#
# class IDF(builtins.object)
#  |  The IDF class holds all the information about an EnergyPlus IDF.
#  |
#  |  Class attributes
#  |  ---------------
#  |  iddname : str
#  |      Name of the IDD currently being used by eppy. As a class attribute, this
#  |      is set for all IDFs which are currently being processed and cannot be
#  |      changed for an individual IDF.
#  |  iddinfo : list
#  |      Comments and metadata about fields in the IDD.
#  |  block : list
#  |      Field names in the IDD.
#  |
#  |  Instance attributes
#  |  -------------------
#  |  idfname : str
#  |      Path to the IDF file.
#  |  idfobjects : list
#  |      List of EpBunch objects in the IDF.
#  |  model : Eplusdata object
#  |      Data dictionary and list of objects for the entire model.
#  |  outputtype : str
#  |      How to format the output of IDF.print or IDF.save, IDF.saveas or
#  |      IDF.savecopy. The options are: 'standard', 'nocomment', 'nocomment1',
#  |      'nocomment2', and 'compressed'.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, idfname=None, epw=None)
#  |      Parameters
#  |      ----------
#  |      idfname : str, optional
#  |          Path to an IDF file (which does not have to exist yet).
#  |      epw : str, optional
#  |          File path to the EPW file to use if running the IDF.
#  |
#  |  copyidfobject(self, idfobject)
#  |      Add an IDF object to the IDF.
#  |
#  |      Parameters
#  |      ----------
#  |      idfobject : EpBunch object
#  |          The IDF object to remove. This usually comes from another idf file,
#  |          or it can be used to copy within this idf file.
#  |
#  |  getextensibleindex(self, key, name)
#  |      Get the index of the first extensible item.
#  |
#  |      Only for internal use. # TODO : hide this
#  |
#  |      Parameters
#  |      ----------
#  |      key : str
#  |          The type of IDF object. This must be in ALL_CAPS.
#  |      name : str
#  |          The name of the object to fetch.
#  |
#  |      Returns
#  |      -------
#  |      int
#  |
#  |  getiddgroupdict(self)
#  |      Return a idd group dictionary
#  |      sample: {'Plant-Condenser Loops': ['PlantLoop', 'CondenserLoop'],
#  |       'Compliance Objects': ['Compliance:Building'], 'Controllers':
#  |       ['Controller:WaterCoil',
#  |        'Controller:OutdoorAir',
#  |        'Controller:MechanicalVentilation',
#  |        'AirLoopHVAC:ControllerList'],
#  |      ...}
#  |
#  |      Returns
#  |      -------
#  |      dict
#  |
#  |  getobject(self, key, name)
#  |      Fetch an IDF object given key and name.
#  |
#  |      Parameters
#  |      ----------
#  |      key : str
#  |          The type of IDF object. This must be in ALL_CAPS.
#  |      name : str
#  |          The name of the object to fetch.
#  |
#  |      Returns
#  |      -------
#  |      EpBunch object.
#  |
#  |  idfstr(self)
#  |      String representation of the IDF.
#  |
#  |      Returns
#  |      -------
#  |      str
#  |
#  |  initnew(self, fname)
#  |      Use the current IDD and create a new empty IDF. If the IDD has not yet
#  |      been initialised then this is done first.
#  |
#  |      Parameters
#  |      ----------
#  |      fname : str, optional
#  |          Path to an IDF. This does not need to be set at this point.
#  |
#  |  initread(self, idfname)
#  |      Use the current IDD and read an IDF from file. If the IDD has not yet
#  |      been initialised then this is done first.
#  |
#  |      Parameters
#  |      ----------
#  |      idf_name : str
#  |          Path to an IDF file.
#  |
#  |  initreadtxt(self, idftxt)
#  |      Use the current IDD and read an IDF from text data. If the IDD has not
#  |      yet been initialised then this is done first.
#  |
#  |      Parameters
#  |      ----------
#  |      idftxt : str
#  |          Text representing an IDF file.
#  |
#  |  new(self, fname=None)
#  |      Create a blank new idf file. Filename is optional.
#  |
#  |      Parameters
#  |      ----------
#  |      fname : str, optional
#  |          Path to an IDF. This does not need to be set at this point.
#  |
#  |  newidfobject(self, key, aname='', **kwargs)
#  |      Add a new idfobject to the model. If you don't specify a value for a
#  |      field, the default value will be set.
#  |
#  |      For example ::
#  |
#  |          newidfobject("CONSTRUCTION")
#  |          newidfobject("CONSTRUCTION",
#  |              Name='Interior Ceiling_class',
#  |              Outside_Layer='LW Concrete',
#  |              Layer_2='soundmat')
#  |
#  |      Parameters
#  |      ----------
#  |      key : str
#  |          The type of IDF object. This must be in ALL_CAPS.
#  |      aname : str, deprecated
#  |          This parameter is not used. It is left there for backward
#  |          compatibility.
#  |      **kwargs
#  |          Keyword arguments in the format `field=value` used to set the value
#  |          of fields in the IDF object when it is created.
#  |
#  |      Returns
#  |      -------
#  |      EpBunch object
#  |
#  |  popidfobject(self, key, index)
#  |      Pop an IDF object from the IDF.
#  |
#  |      Parameters
#  |      ----------
#  |      key : str
#  |          The type of IDF object. This must be in ALL_CAPS.
#  |      index : int
#  |          The index of the object to pop.
#  |
#  |      Returns
#  |      -------
#  |      EpBunch object.
#  |
#  |  printidf(self)
#  |      Print the IDF.
#  |
#  |  read(self)
#  |      Read the IDF file and the IDD file. If the IDD file had already been
#  |      read, it will not be read again.
#  |
#  |      Read populates the following data structures:
#  |
#  |      - idfobjects : list
#  |      - model : list
#  |      - idd_info : list
#  |      - idd_index : dict
#  |
#  |  removeextensibles(self, key, name)
#  |      Remove extensible items in the object of key and name.
#  |
#  |      Only for internal use. # TODO : hide this
#  |
#  |      Parameters
#  |      ----------
#  |      key : str
#  |          The type of IDF object. This must be in ALL_CAPS.
#  |      name : str
#  |          The name of the object to fetch.
#  |
#  |      Returns
#  |      -------
#  |      EpBunch object
#  |
#  |  removeidfobject(self, idfobject)
#  |      Remove an IDF object from the IDF.
#  |
#  |      Parameters
#  |      ----------
#  |      idfobject : EpBunch object
#  |          The IDF object to remove.
#  |
#  |  run(self, **kwargs)
#  |      This method wraps the following method:
#  |
#  |      run(idf=None, weather=None, output_directory='', annual=False, design_day=False, idd=None, epmacro=False, expandobjects=False, readvars=False, output_prefix=None, output_suffix=None, version=False, verbose='v', ep_version=None)
#  |          Wrapper around the EnergyPlus command line interface.
#  |
#  |          Parameters
#  |          ----------
#  |          idf : str
#  |              Full or relative path to the IDF file to be run, or an IDF object.
#  |
#  |          weather : str
#  |              Full or relative path to the weather file.
#  |
#  |          output_directory : str, optional
#  |              Full or relative path to an output directory (default: 'run_outputs)
#  |
#  |          annual : bool, optional
#  |              If True then force annual simulation (default: False)
#  |
#  |          design_day : bool, optional
#  |              Force design-day-only simulation (default: False)
#  |
#  |          idd : str, optional
#  |              Input data dictionary (default: Energy+.idd in EnergyPlus directory)
#  |
#  |          epmacro : str, optional
#  |              Run EPMacro prior to simulation (default: False).
#  |
#  |          expandobjects : bool, optional
#  |              Run ExpandObjects prior to simulation (default: False)
#  |
#  |          readvars : bool, optional
#  |              Run ReadVarsESO after simulation (default: False)
#  |
#  |          output_prefix : str, optional
#  |              Prefix for output file names (default: eplus)
#  |
#  |          output_suffix : str, optional
#  |              Suffix style for output file names (default: L)
#  |                  L: Legacy (e.g., eplustbl.csv)
#  |                  C: Capital (e.g., eplusTable.csv)
#  |                  D: Dash (e.g., eplus-table.csv)
#  |
#  |          version : bool, optional
#  |              Display version information (default: False)
#  |
#  |          verbose: str
#  |              Set verbosity of runtime messages (default: v)
#  |                  v: verbose
#  |                  q: quiet
#  |
#  |          ep_version: str
#  |              EnergyPlus version, used to find install directory. Required if run() is
#  |              called with an IDF file path rather than an IDF object.
#  |
#  |          Returns
#  |          -------
#  |          str : status
#  |
#  |          Raises
#  |          ------
#  |          CalledProcessError
#  |
#  |          AttributeError
#  |              If no ep_version parameter is passed when calling with an IDF file path
#  |              rather than an IDF object.
#  |
#  |  save(self, filename=None, lineendings='default', encoding='latin-1')
#  |      Save the IDF as a text file with the optional filename passed, or with
#  |      the current idfname of the IDF.
#  |
#  |      Parameters
#  |      ----------
#  |      filename : str, optional
#  |          Filepath to save the file. If None then use the IDF.idfname
#  |          parameter. Also accepts a file handle.
#  |
#  |      lineendings : str, optional
#  |          Line endings to use in the saved file. Options are 'default',
#  |          'windows' and 'unix' the default is 'default' which uses the line
#  |          endings for the current system.
#  |
#  |      encoding : str, optional
#  |          Encoding to use for the saved file. The default is 'latin-1' which
#  |          is compatible with the EnergyPlus IDFEditor.
#  |
#  |  saveas(self, filename, lineendings='default', encoding='latin-1')
#  |      Save the IDF as a text file with the filename passed.
#  |
#  |      Parameters
#  |      ----------
#  |      filename : str
#  |          Filepath to to set the idfname attribute to and save the file as.
#  |
#  |      lineendings : str, optional
#  |          Line endings to use in the saved file. Options are 'default',
#  |          'windows' and 'unix' the default is 'default' which uses the line
#  |          endings for the current system.
#  |
#  |      encoding : str, optional
#  |          Encoding to use for the saved file. The default is 'latin-1' which
#  |          is compatible with the EnergyPlus IDFEditor.
#  |
#  |  savecopy(self, filename, lineendings='default', encoding='latin-1')
#  |      Save a copy of the file with the filename passed.
#  |
#  |      Parameters
#  |      ----------
#  |      filename : str
#  |          Filepath to save the file.
#  |
#  |      lineendings : str, optional
#  |          Line endings to use in the saved file. Options are 'default',
#  |          'windows' and 'unix' the default is 'default' which uses the line
#  |          endings for the current system.
#  |
#  |      encoding : str, optional
#  |          Encoding to use for the saved file. The default is 'latin-1' which
#  |          is compatible with the EnergyPlus IDFEditor.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  getiddname() from builtins.type
#  |      Get the name of the current IDD used by eppy.
#  |
#  |      Returns
#  |      -------
#  |      str
#  |
#  |  setidd(iddinfo, iddindex, block, idd_version) from builtins.type
#  |      Set the IDD to be used by eppy.
#  |
#  |      Parameters
#  |      ----------
#  |      iddinfo : list
#  |          Comments and metadata about fields in the IDD.
#  |      block : list
#  |          Field names in the IDD.
#  |
#  |  setiddname(iddname, testing=False) from builtins.type
#  |      Set the path to the EnergyPlus IDD for the version of EnergyPlus which
#  |      is to be used by eppy.
#  |
#  |      Parameters
#  |      ----------
#  |      iddname : str
#  |          Path to the IDD file.
#  |      testing : bool
#  |          Flag to use if running tests since we may want to ignore the
#  |          `IDDAlreadySetError`.
#  |
#  |      Raises
#  |      ------
#  |      IDDAlreadySetError
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  block = [['Version', 'A1'], ['SimulationControl', 'A1', 'A2', 'A3', 'A...
#  |
#  |  idd_index = {'name2refs': {'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:CONS...
#  |
#  |  idd_info = [[{'format': ['singleLine'], 'group': 'Simulation Parameter...
#  |
#  |  idd_version = (8, 9, 0)
#  |
#  |  iddname = r'C:\EnergyPlusV8-9-0\Energy+.idd'

# %%
print(dir(IDF))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'block', 'copyidfobject', 'getextensibleindex', 'getiddgroupdict', 'getiddname', 'getobject', 'idd_index', 'idd_info', 'idd_version', 'iddname', 'idfstr', 'initnew', 'initread', 'initreadtxt', 'new', 'newidfobject', 'popidfobject', 'printidf', 'read', 'removeextensibles', 'removeidfobject', 'run', 'save', 'saveas', 'savecopy', 'setidd', 'setiddname']

# %% [markdown]
# ### Set 'iddfile' class attribute

# %%
iddfile = r'C:\EnergyPlusV8-9-0\Energy+.idd'
IDF.setiddname(iddfile)
IDF.iddname
# Out:
# 'C:\\EnergyPlusV8-9-0\\Energy+.idd'

# %% [markdown]
# ## Reading an idf file

# %% [markdown]
# ### Create an instance and read in an .idf file

# %%
idf=IDF()
idf.idfname='1ZoneUncontrolled.idf'
idf.read()
idf

# %% [markdown]
# ### Print the idf as a text string
#
# This is how the text file itself looks from within the IDF class

# %%
idf.printidf()
# Out:
# Version,
#     8.9;                      !- Version Identifier
#
# SimulationControl,
#     No,                       !- Do Zone Sizing Calculation
#     No,                       !- Do System Sizing Calculation
#     No,                       !- Do Plant Sizing Calculation
#     Yes,                      !- Run Simulation for Sizing Periods
#     Yes;                      !- Run Simulation for Weather File Run Periods
#
# Building,
#     Simple One Zone (Wireframe DXF),    !- Name
#     0.0,                      !- North Axis
#     Suburbs,                  !- Terrain
#     0.04,                     !- Loads Convergence Tolerance Value
#     0.004,                    !- Temperature Convergence Tolerance Value
#     MinimalShadowing,         !- Solar Distribution
#     30,                       !- Maximum Number of Warmup Days
#     6;                        !- Minimum Number of Warmup Days
#
# SurfaceConvectionAlgorithm:Inside,
#     TARP;                     !- Algorithm
#
# SurfaceConvectionAlgorithm:Outside,
#     DOE-2;                    !- Algorithm
#
# HeatBalanceAlgorithm,
#     ConductionTransferFunction;    !- Algorithm
#
# Timestep,
#     4;                        !- Number of Timesteps per Hour
#
# Site:Location,
#     Denver Centennial  Golden   N_CO_USA Design_Conditions,    !- Name
#     39.74,                    !- Latitude
#     -105.18,                  !- Longitude
#     -7.0,                     !- Time Zone
#     1829.0;                   !- Elevation
#
# SizingPeriod:DesignDay,
#     Denver Centennial  Golden   N Ann Htg 99% Condns DB,    !- Name
#     12,                       !- Month
#     21,                       !- Day of Month
#     WinterDesignDay,          !- Day Type
#     -15.5,                    !- Maximum DryBulb Temperature
#     0.0,                      !- Daily DryBulb Temperature Range
#     ,                         !- DryBulb Temperature Range Modifier Type
#     ,                         !- DryBulb Temperature Range Modifier Day Schedule Name
#     Wetbulb,                  !- Humidity Condition Type
#     -15.5,                    !- Wetbulb or DewPoint at Maximum DryBulb
#     ,                         !- Humidity Condition Day Schedule Name
#     ,                         !- Humidity Ratio at Maximum DryBulb
#     ,                         !- Enthalpy at Maximum DryBulb
#     ,                         !- Daily WetBulb Temperature Range
#     81198.0,                  !- Barometric Pressure
#     3.0,                      !- Wind Speed
#     340.0,                    !- Wind Direction
#     No,                       !- Rain Indicator
#     No,                       !- Snow Indicator
#     No,                       !- Daylight Saving Time Indicator
#     ASHRAEClearSky,           !- Solar Model Indicator
#     ,                         !- Beam Solar Day Schedule Name
#     ,                         !- Diffuse Solar Day Schedule Name
#     ,                         !- ASHRAE Clear Sky Optical Depth for Beam Irradiance taub
#     ,                         !- ASHRAE Clear Sky Optical Depth for Diffuse Irradiance taud
#     0.0;                      !- Sky Clearness
#
# SizingPeriod:DesignDay,
#     Denver Centennial  Golden   N Ann Clg 1% Condns DB=>MWB,    !- Name
#     7,                        !- Month
#     21,                       !- Day of Month
#     SummerDesignDay,          !- Day Type
#     32.0,                     !- Maximum DryBulb Temperature
#     15.2,                     !- Daily DryBulb Temperature Range
#     ,                         !- DryBulb Temperature Range Modifier Type
#     ,                         !- DryBulb Temperature Range Modifier Day Schedule Name
#     Wetbulb,                  !- Humidity Condition Type
#     15.5,                     !- Wetbulb or DewPoint at Maximum DryBulb
#     ,                         !- Humidity Condition Day Schedule Name
#     ,                         !- Humidity Ratio at Maximum DryBulb
#     ,                         !- Enthalpy at Maximum DryBulb
#     ,                         !- Daily WetBulb Temperature Range
#     81198.0,                  !- Barometric Pressure
#     4.9,                      !- Wind Speed
#     0.0,                      !- Wind Direction
#     No,                       !- Rain Indicator
#     No,                       !- Snow Indicator
#     No,                       !- Daylight Saving Time Indicator
#     ASHRAEClearSky,           !- Solar Model Indicator
#     ,                         !- Beam Solar Day Schedule Name
#     ,                         !- Diffuse Solar Day Schedule Name
#     ,                         !- ASHRAE Clear Sky Optical Depth for Beam Irradiance taub
#     ,                         !- ASHRAE Clear Sky Optical Depth for Diffuse Irradiance taud
#     1.0;                      !- Sky Clearness
#
# RunPeriod,
#     ,                         !- Name
#     1,                        !- Begin Month
#     1,                        !- Begin Day of Month
#     12,                       !- End Month
#     31,                       !- End Day of Month
#     Tuesday,                  !- Day of Week for Start Day
#     Yes,                      !- Use Weather File Holidays and Special Days
#     Yes,                      !- Use Weather File Daylight Saving Period
#     No,                       !- Apply Weekend Holiday Rule
#     Yes,                      !- Use Weather File Rain Indicators
#     Yes;                      !- Use Weather File Snow Indicators
#
# ScheduleTypeLimits,
#     Fraction,                 !- Name
#     0.0,                      !- Lower Limit Value
#     1.0,                      !- Upper Limit Value
#     CONTINUOUS;               !- Numeric Type
#
# ScheduleTypeLimits,
#     On/Off,                   !- Name
#     0,                        !- Lower Limit Value
#     1,                        !- Upper Limit Value
#     DISCRETE;                 !- Numeric Type
#
# Schedule:Constant,
#     AlwaysOn,                 !- Name
#     On/Off,                   !- Schedule Type Limits Name
#     1.0;                      !- Hourly Value
#
# Material,
#     C5 - 4 IN HW CONCRETE,    !- Name
#     MediumRough,              !- Roughness
#     0.1014984,                !- Thickness
#     1.729577,                 !- Conductivity
#     2242.585,                 !- Density
#     836.8,                    !- Specific Heat
#     0.9,                      !- Thermal Absorptance
#     0.65,                     !- Solar Absorptance
#     0.65;                     !- Visible Absorptance
#
# Material:NoMass,
#     R13LAYER,                 !- Name
#     Rough,                    !- Roughness
#     2.290965,                 !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.75,                     !- Solar Absorptance
#     0.75;                     !- Visible Absorptance
#
# Material:NoMass,
#     R31LAYER,                 !- Name
#     Rough,                    !- Roughness
#     5.456,                    !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.75,                     !- Solar Absorptance
#     0.75;                     !- Visible Absorptance
#
# Construction,
#     R13WALL,                  !- Name
#     R13LAYER;                 !- Outside Layer
#
# Construction,
#     FLOOR,                    !- Name
#     C5 - 4 IN HW CONCRETE;    !- Outside Layer
#
# Construction,
#     ROOF31,                   !- Name
#     R31LAYER;                 !- Outside Layer
#
# GlobalGeometryRules,
#     UpperLeftCorner,          !- Starting Vertex Position
#     CounterClockWise,         !- Vertex Entry Direction
#     World;                    !- Coordinate System
#
# Zone,
#     ZONE ONE,                 !- Name
#     0.0,                      !- Direction of Relative North
#     0.0,                      !- X Origin
#     0.0,                      !- Y Origin
#     0.0,                      !- Z Origin
#     1,                        !- Type
#     1,                        !- Multiplier
#     autocalculate,            !- Ceiling Height
#     autocalculate;            !- Volume
#
# BuildingSurface:Detailed,
#     Zn001:Wall001,            !- Name
#     Wall,                     !- Surface Type
#     R13WALL,                  !- Construction Name
#     ZONE ONE,                 !- Zone Name
#     Outdoors,                 !- Outside Boundary Condition
#     ,                         !- Outside Boundary Condition Object
#     SunExposed,               !- Sun Exposure
#     WindExposed,              !- Wind Exposure
#     0.5,                      !- View Factor to Ground
#     4,                        !- Number of Vertices
#     0.0,                      !- Vertex 1 Xcoordinate
#     0.0,                      !- Vertex 1 Ycoordinate
#     4.572,                    !- Vertex 1 Zcoordinate
#     0.0,                      !- Vertex 2 Xcoordinate
#     0.0,                      !- Vertex 2 Ycoordinate
#     0.0,                      !- Vertex 2 Zcoordinate
#     15.24,                    !- Vertex 3 Xcoordinate
#     0.0,                      !- Vertex 3 Ycoordinate
#     0.0,                      !- Vertex 3 Zcoordinate
#     15.24,                    !- Vertex 4 Xcoordinate
#     0.0,                      !- Vertex 4 Ycoordinate
#     4.572;                    !- Vertex 4 Zcoordinate
#
# BuildingSurface:Detailed,
#     Zn001:Wall002,            !- Name
#     Wall,                     !- Surface Type
#     R13WALL,                  !- Construction Name
#     ZONE ONE,                 !- Zone Name
#     Outdoors,                 !- Outside Boundary Condition
#     ,                         !- Outside Boundary Condition Object
#     SunExposed,               !- Sun Exposure
#     WindExposed,              !- Wind Exposure
#     0.5,                      !- View Factor to Ground
#     4,                        !- Number of Vertices
#     15.24,                    !- Vertex 1 Xcoordinate
#     0.0,                      !- Vertex 1 Ycoordinate
#     4.572,                    !- Vertex 1 Zcoordinate
#     15.24,                    !- Vertex 2 Xcoordinate
#     0.0,                      !- Vertex 2 Ycoordinate
#     0.0,                      !- Vertex 2 Zcoordinate
#     15.24,                    !- Vertex 3 Xcoordinate
#     15.24,                    !- Vertex 3 Ycoordinate
#     0.0,                      !- Vertex 3 Zcoordinate
#     15.24,                    !- Vertex 4 Xcoordinate
#     15.24,                    !- Vertex 4 Ycoordinate
#     4.572;                    !- Vertex 4 Zcoordinate
#
# BuildingSurface:Detailed,
#     Zn001:Wall003,            !- Name
#     Wall,                     !- Surface Type
#     R13WALL,                  !- Construction Name
#     ZONE ONE,                 !- Zone Name
#     Outdoors,                 !- Outside Boundary Condition
#     ,                         !- Outside Boundary Condition Object
#     SunExposed,               !- Sun Exposure
#     WindExposed,              !- Wind Exposure
#     0.5,                      !- View Factor to Ground
#     4,                        !- Number of Vertices
#     15.24,                    !- Vertex 1 Xcoordinate
#     15.24,                    !- Vertex 1 Ycoordinate
#     4.572,                    !- Vertex 1 Zcoordinate
#     15.24,                    !- Vertex 2 Xcoordinate
#     15.24,                    !- Vertex 2 Ycoordinate
#     0.0,                      !- Vertex 2 Zcoordinate
#     0.0,                      !- Vertex 3 Xcoordinate
#     15.24,                    !- Vertex 3 Ycoordinate
#     0.0,                      !- Vertex 3 Zcoordinate
#     0.0,                      !- Vertex 4 Xcoordinate
#     15.24,                    !- Vertex 4 Ycoordinate
#     4.572;                    !- Vertex 4 Zcoordinate
#
# BuildingSurface:Detailed,
#     Zn001:Wall004,            !- Name
#     Wall,                     !- Surface Type
#     R13WALL,                  !- Construction Name
#     ZONE ONE,                 !- Zone Name
#     Outdoors,                 !- Outside Boundary Condition
#     ,                         !- Outside Boundary Condition Object
#     SunExposed,               !- Sun Exposure
#     WindExposed,              !- Wind Exposure
#     0.5,                      !- View Factor to Ground
#     4,                        !- Number of Vertices
#     0.0,                      !- Vertex 1 Xcoordinate
#     15.24,                    !- Vertex 1 Ycoordinate
#     4.572,                    !- Vertex 1 Zcoordinate
#     0.0,                      !- Vertex 2 Xcoordinate
#     15.24,                    !- Vertex 2 Ycoordinate
#     0.0,                      !- Vertex 2 Zcoordinate
#     0.0,                      !- Vertex 3 Xcoordinate
#     0.0,                      !- Vertex 3 Ycoordinate
#     0.0,                      !- Vertex 3 Zcoordinate
#     0.0,                      !- Vertex 4 Xcoordinate
#     0.0,                      !- Vertex 4 Ycoordinate
#     4.572;                    !- Vertex 4 Zcoordinate
#
# BuildingSurface:Detailed,
#     Zn001:Flr001,             !- Name
#     Floor,                    !- Surface Type
#     FLOOR,                    !- Construction Name
#     ZONE ONE,                 !- Zone Name
#     Adiabatic,                !- Outside Boundary Condition
#     ,                         !- Outside Boundary Condition Object
#     NoSun,                    !- Sun Exposure
#     NoWind,                   !- Wind Exposure
#     1.0,                      !- View Factor to Ground
#     4,                        !- Number of Vertices
#     15.24,                    !- Vertex 1 Xcoordinate
#     0.0,                      !- Vertex 1 Ycoordinate
#     0.0,                      !- Vertex 1 Zcoordinate
#     0.0,                      !- Vertex 2 Xcoordinate
#     0.0,                      !- Vertex 2 Ycoordinate
#     0.0,                      !- Vertex 2 Zcoordinate
#     0.0,                      !- Vertex 3 Xcoordinate
#     15.24,                    !- Vertex 3 Ycoordinate
#     0.0,                      !- Vertex 3 Zcoordinate
#     15.24,                    !- Vertex 4 Xcoordinate
#     15.24,                    !- Vertex 4 Ycoordinate
#     0.0;                      !- Vertex 4 Zcoordinate
#
# BuildingSurface:Detailed,
#     Zn001:Roof001,            !- Name
#     Roof,                     !- Surface Type
#     ROOF31,                   !- Construction Name
#     ZONE ONE,                 !- Zone Name
#     Outdoors,                 !- Outside Boundary Condition
#     ,                         !- Outside Boundary Condition Object
#     SunExposed,               !- Sun Exposure
#     WindExposed,              !- Wind Exposure
#     0.0,                      !- View Factor to Ground
#     4,                        !- Number of Vertices
#     0.0,                      !- Vertex 1 Xcoordinate
#     15.24,                    !- Vertex 1 Ycoordinate
#     4.572,                    !- Vertex 1 Zcoordinate
#     0.0,                      !- Vertex 2 Xcoordinate
#     0.0,                      !- Vertex 2 Ycoordinate
#     4.572,                    !- Vertex 2 Zcoordinate
#     15.24,                    !- Vertex 3 Xcoordinate
#     0.0,                      !- Vertex 3 Ycoordinate
#     4.572,                    !- Vertex 3 Zcoordinate
#     15.24,                    !- Vertex 4 Xcoordinate
#     15.24,                    !- Vertex 4 Ycoordinate
#     4.572;                    !- Vertex 4 Zcoordinate
#
# OtherEquipment,
#     Test 352a,                !- Name
#     None,                     !- Fuel Type
#     ZONE ONE,                 !- Zone or ZoneList Name
#     AlwaysOn,                 !- Schedule Name
#     EquipmentLevel,           !- Design Level Calculation Method
#     352.0,                    !- Design Level
#     ,                         !- Power per Zone Floor Area
#     ,                         !- Power per Person
#     0.0,                      !- Fraction Latent
#     0.0,                      !- Fraction Radiant
#     0.0;                      !- Fraction Lost
#
# OtherEquipment,
#     Test 352 minus,           !- Name
#     None,                     !- Fuel Type
#     ZONE ONE,                 !- Zone or ZoneList Name
#     AlwaysOn,                 !- Schedule Name
#     EquipmentLevel,           !- Design Level Calculation Method
#     -352.0,                   !- Design Level
#     ,                         !- Power per Zone Floor Area
#     ,                         !- Power per Person
#     0.0,                      !- Fraction Latent
#     0.0,                      !- Fraction Radiant
#     0.0;                      !- Fraction Lost
#
# Exterior:Lights,
#     ExtLights,                !- Name
#     AlwaysOn,                 !- Schedule Name
#     5250.0,                   !- Design Level
#     AstronomicalClock,        !- Control Option
#     Grounds Lights;           !- EndUse Subcategory
#
# Output:VariableDictionary,
#     IDF;                      !- Key Field
#
# Output:Surfaces:Drawing,
#     dxf:wireframe;            !- Report Type
#
# Output:Constructions,
#     Constructions;            !- Details Type 1
#
# Output:Table:SummaryReports,
#     AllSummary;               !- Report 1 Name
#
# OutputControl:Table:Style,
#     ALL;                      !- Column Separator
#
# Output:Variable,
#     *,                        !- Key Value
#     Site Outdoor Air Drybulb Temperature,    !- Variable Name
#     hourly;                   !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Site Daylight Saving Time Status,    !- Variable Name
#     daily;                    !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Site Day Type Index,      !- Variable Name
#     daily;                    !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Zone Mean Air Temperature,    !- Variable Name
#     hourly;                   !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Zone Total Internal Latent Gain Energy,    !- Variable Name
#     hourly;                   !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Zone Mean Radiant Temperature,    !- Variable Name
#     hourly;                   !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Zone Air Heat Balance Surface Convection Rate,    !- Variable Name
#     hourly;                   !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Zone Air Heat Balance Air Energy Storage Rate,    !- Variable Name
#     hourly;                   !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Surface Inside Face Temperature,    !- Variable Name
#     daily;                    !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Surface Outside Face Temperature,    !- Variable Name
#     daily;                    !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Surface Inside Face Convection Heat Transfer Coefficient,    !- Variable Name
#     daily;                    !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Surface Outside Face Convection Heat Transfer Coefficient,    !- Variable Name
#     daily;                    !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Other Equipment Total Heating Energy,    !- Variable Name
#     monthly;                  !- Reporting Frequency
#
# Output:Variable,
#     *,                        !- Key Value
#     Zone Other Equipment Total Heating Energy,    !- Variable Name
#     monthly;                  !- Reporting Frequency
#
# Output:Meter:MeterFileOnly,
#     ExteriorLights:Electricity,    !- Key Name
#     hourly;                   !- Reporting Frequency
#
# Output:Meter:MeterFileOnly,
#     EnergyTransfer:Building,    !- Key Name
#     hourly;                   !- Reporting Frequency
#
# Output:Meter:MeterFileOnly,
#     EnergyTransfer:Facility,    !- Key Name
#     hourly;                   !- Reporting Frequency

# %% [markdown]
# ### Print the idf as a dictionary

# %%
idf.idfobjects
# Out:
# {'VERSION': [
#  Version,
#      8.9;                      !- Version Identifier
#  ], 'SIMULATIONCONTROL': [
#  SimulationControl,
#      No,                       !- Do Zone Sizing Calculation
#      No,                       !- Do System Sizing Calculation
#      No,                       !- Do Plant Sizing Calculation
#      Yes,                      !- Run Simulation for Sizing Periods
#      Yes;                      !- Run Simulation for Weather File Run Periods
#  ], 'BUILDING': [
#  Building,
#      Simple One Zone (Wireframe DXF),    !- Name
#      0.0,                      !- North Axis
#      Suburbs,                  !- Terrain
#      0.04,                     !- Loads Convergence Tolerance Value
#      0.004,                    !- Temperature Convergence Tolerance Value
#      MinimalShadowing,         !- Solar Distribution
#      30,                       !- Maximum Number of Warmup Days
#      6;                        !- Minimum Number of Warmup Days
#  ], 'SHADOWCALCULATION': [], 'SURFACECONVECTIONALGORITHM:INSIDE': [
#  SurfaceConvectionAlgorithm:Inside,
#      TARP;                     !- Algorithm
#  ], 'SURFACECONVECTIONALGORITHM:OUTSIDE': [
#  SurfaceConvectionAlgorithm:Outside,
#      DOE-2;                    !- Algorithm
#  ], 'HEATBALANCEALGORITHM': [
#  HeatBalanceAlgorithm,
#      ConductionTransferFunction;    !- Algorithm
#  ], 'HEATBALANCESETTINGS:CONDUCTIONFINITEDIFFERENCE': [], 'ZONEAIRHEATBALANCEALGORITHM': [], 'ZONEAIRCONTAMINANTBALANCE': [], 'ZONEAIRMASSFLOWCONSERVATION': [], 'ZONECAPACITANCEMULTIPLIER:RESEARCHSPECIAL': [], 'TIMESTEP': [
#  Timestep,
#      4;                        !- Number of Timesteps per Hour
#  ], 'CONVERGENCELIMITS': [], 'HVACSYSTEMROOTFINDINGALGORITHM': [], 'COMPLIANCE:BUILDING': [], 'SITE:LOCATION': [
#  Site:Location,
#      Denver Centennial  Golden   N_CO_USA Design_Conditions,    !- Name
#      39.74,                    !- Latitude
#      -105.18,                  !- Longitude
#      -7.0,                     !- Time Zone
#      1829.0;                   !- Elevation
#  ], 'SITE:VARIABLELOCATION': [], 'SIZINGPERIOD:DESIGNDAY': [
#  SizingPeriod:DesignDay,
#      Denver Centennial  Golden   N Ann Htg 99% Condns DB,    !- Name
#      12,                       !- Month
#      21,                       !- Day of Month
#      WinterDesignDay,          !- Day Type
#      -15.5,                    !- Maximum DryBulb Temperature
#      0.0,                      !- Daily DryBulb Temperature Range
#      ,                         !- DryBulb Temperature Range Modifier Type
#      ,                         !- DryBulb Temperature Range Modifier Day Schedule Name
#      Wetbulb,                  !- Humidity Condition Type
#      -15.5,                    !- Wetbulb or DewPoint at Maximum DryBulb
#      ,                         !- Humidity Condition Day Schedule Name
#      ,                         !- Humidity Ratio at Maximum DryBulb
#      ,                         !- Enthalpy at Maximum DryBulb
#      ,                         !- Daily WetBulb Temperature Range
#      81198.0,                  !- Barometric Pressure
#      3.0,                      !- Wind Speed
#      340.0,                    !- Wind Direction
#      No,                       !- Rain Indicator
#      No,                       !- Snow Indicator
#      No,                       !- Daylight Saving Time Indicator
#      ASHRAEClearSky,           !- Solar Model Indicator
#      ,                         !- Beam Solar Day Schedule Name
#      ,                         !- Diffuse Solar Day Schedule Name
#      ,                         !- ASHRAE Clear Sky Optical Depth for Beam Irradiance taub
#      ,                         !- ASHRAE Clear Sky Optical Depth for Diffuse Irradiance taud
#      0.0;                      !- Sky Clearness
#  ,
#  SizingPeriod:DesignDay,
#      Denver Centennial  Golden   N Ann Clg 1% Condns DB=>MWB,    !- Name
#      7,                        !- Month
#      21,                       !- Day of Month
#      SummerDesignDay,          !- Day Type
#      32.0,                     !- Maximum DryBulb Temperature
#      15.2,                     !- Daily DryBulb Temperature Range
#      ,                         !- DryBulb Temperature Range Modifier Type
#      ,                         !- DryBulb Temperature Range Modifier Day Schedule Name
#      Wetbulb,                  !- Humidity Condition Type
#      15.5,                     !- Wetbulb or DewPoint at Maximum DryBulb
#      ,                         !- Humidity Condition Day Schedule Name
#      ,                         !- Humidity Ratio at Maximum DryBulb
#      ,                         !- Enthalpy at Maximum DryBulb
#      ,                         !- Daily WetBulb Temperature Range
#      81198.0,                  !- Barometric Pressure
#      4.9,                      !- Wind Speed
#      0.0,                      !- Wind Direction
#      No,                       !- Rain Indicator
#      No,                       !- Snow Indicator
#      No,                       !- Daylight Saving Time Indicator
#      ASHRAEClearSky,           !- Solar Model Indicator
#      ,                         !- Beam Solar Day Schedule Name
#      ,                         !- Diffuse Solar Day Schedule Name
#      ,                         !- ASHRAE Clear Sky Optical Depth for Beam Irradiance taub
#      ,                         !- ASHRAE Clear Sky Optical Depth for Diffuse Irradiance taud
#      1.0;                      !- Sky Clearness
#  ], 'SIZINGPERIOD:WEATHERFILEDAYS': [], 'SIZINGPERIOD:WEATHERFILECONDITIONTYPE': [], 'RUNPERIOD': [
#  RunPeriod,
#      ,                         !- Name
#      1,                        !- Begin Month
#      1,                        !- Begin Day of Month
#      12,                       !- End Month
#      31,                       !- End Day of Month
#      Tuesday,                  !- Day of Week for Start Day
#      Yes,                      !- Use Weather File Holidays and Special Days
#      Yes,                      !- Use Weather File Daylight Saving Period
#      No,                       !- Apply Weekend Holiday Rule
#      Yes,                      !- Use Weather File Rain Indicators
#      Yes;                      !- Use Weather File Snow Indicators
#  ], 'RUNPERIOD:CUSTOMRANGE': [], 'RUNPERIODCONTROL:SPECIALDAYS': [], 'RUNPERIODCONTROL:DAYLIGHTSAVINGTIME': [], 'WEATHERPROPERTY:SKYTEMPERATURE': [], 'SITE:WEATHERSTATION': [], 'SITE:HEIGHTVARIATION': [], 'SITE:GROUNDTEMPERATURE:BUILDINGSURFACE': [], 'SITE:GROUNDTEMPERATURE:FCFACTORMETHOD': [], 'SITE:GROUNDTEMPERATURE:SHALLOW': [], 'SITE:GROUNDTEMPERATURE:DEEP': [], 'SITE:GROUNDTEMPERATURE:UNDISTURBED:FINITEDIFFERENCE': [], 'SITE:GROUNDTEMPERATURE:UNDISTURBED:KUSUDAACHENBACH': [], 'SITE:GROUNDTEMPERATURE:UNDISTURBED:XING': [], 'SITE:GROUNDDOMAIN:SLAB': [], 'SITE:GROUNDDOMAIN:BASEMENT': [], 'SITE:GROUNDREFLECTANCE': [], 'SITE:GROUNDREFLECTANCE:SNOWMODIFIER': [], 'SITE:WATERMAINSTEMPERATURE': [], 'SITE:PRECIPITATION': [], 'ROOFIRRIGATION': [], 'SITE:SOLARANDVISIBLESPECTRUM': [], 'SITE:SPECTRUMDATA': [], 'SCHEDULETYPELIMITS': [
#  ScheduleTypeLimits,
#      Fraction,                 !- Name
#      0.0,                      !- Lower Limit Value
#      1.0,                      !- Upper Limit Value
#      CONTINUOUS;               !- Numeric Type
#  ,
#  ScheduleTypeLimits,
#      On/Off,                   !- Name
#      0,                        !- Lower Limit Value
#      1,                        !- Upper Limit Value
#      DISCRETE;                 !- Numeric Type
#  ], 'SCHEDULE:DAY:HOURLY': [], 'SCHEDULE:DAY:INTERVAL': [], 'SCHEDULE:DAY:LIST': [], 'SCHEDULE:WEEK:DAILY': [], 'SCHEDULE:WEEK:COMPACT': [], 'SCHEDULE:YEAR': [], 'SCHEDULE:COMPACT': [], 'SCHEDULE:CONSTANT': [
#  Schedule:Constant,
#      AlwaysOn,                 !- Name
#      On/Off,                   !- Schedule Type Limits Name
#      1.0;                      !- Hourly Value
#  ], 'SCHEDULE:FILE:SHADING': [], 'SCHEDULE:FILE': [], 'MATERIAL': [
#  Material,
#      C5 - 4 IN HW CONCRETE,    !- Name
#      MediumRough,              !- Roughness
#      0.1014984,                !- Thickness
#      1.729577,                 !- Conductivity
#      2242.585,                 !- Density
#      836.8,                    !- Specific Heat
#      0.9,                      !- Thermal Absorptance
#      0.65,                     !- Solar Absorptance
#      0.65;                     !- Visible Absorptance
#  ], 'MATERIAL:NOMASS': [
#  Material:NoMass,
#      R13LAYER,                 !- Name
#      Rough,                    !- Roughness
#      2.290965,                 !- Thermal Resistance
#      0.9,                      !- Thermal Absorptance
#      0.75,                     !- Solar Absorptance
#      0.75;                     !- Visible Absorptance
#  ,
#  Material:NoMass,
#      R31LAYER,                 !- Name
#      Rough,                    !- Roughness
#      5.456,                    !- Thermal Resistance
#      0.9,                      !- Thermal Absorptance
#      0.75,                     !- Solar Absorptance
#      0.75;                     !- Visible Absorptance
#  ], 'MATERIAL:INFRAREDTRANSPARENT': [], 'MATERIAL:AIRGAP': [], 'MATERIAL:ROOFVEGETATION': [], 'WINDOWMATERIAL:SIMPLEGLAZINGSYSTEM': [], 'WINDOWMATERIAL:GLAZING': [], 'WINDOWMATERIAL:GLAZINGGROUP:THERMOCHROMIC': [], 'WINDOWMATERIAL:GLAZING:REFRACTIONEXTINCTIONMETHOD': [], 'WINDOWMATERIAL:GAS': [], 'WINDOWGAP:SUPPORTPILLAR': [], 'WINDOWGAP:DEFLECTIONSTATE': [], 'WINDOWMATERIAL:GASMIXTURE': [], 'WINDOWMATERIAL:GAP': [], 'WINDOWMATERIAL:SHADE': [], 'WINDOWMATERIAL:COMPLEXSHADE': [], 'WINDOWMATERIAL:BLIND': [], 'WINDOWMATERIAL:SCREEN': [], 'WINDOWMATERIAL:SHADE:EQUIVALENTLAYER': [], 'WINDOWMATERIAL:DRAPE:EQUIVALENTLAYER': [], 'WINDOWMATERIAL:BLIND:EQUIVALENTLAYER': [], 'WINDOWMATERIAL:SCREEN:EQUIVALENTLAYER': [], 'WINDOWMATERIAL:GLAZING:EQUIVALENTLAYER': [], 'WINDOWMATERIAL:GAP:EQUIVALENTLAYER': [], 'MATERIALPROPERTY:MOISTUREPENETRATIONDEPTH:SETTINGS': [], 'MATERIALPROPERTY:PHASECHANGE': [], 'MATERIALPROPERTY:PHASECHANGEHYSTERESIS': [], 'MATERIALPROPERTY:VARIABLETHERMALCONDUCTIVITY': [], 'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:SETTINGS': [], 'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:SORPTIONISOTHERM': [], 'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:SUCTION': [], 'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:REDISTRIBUTION': [], 'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:DIFFUSION': [], 'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:THERMALCONDUCTIVITY': [], 'MATERIALPROPERTY:GLAZINGSPECTRALDATA': [], 'CONSTRUCTION': [
#  Construction,
#      R13WALL,                  !- Name
#      R13LAYER;                 !- Outside Layer
#  ,
#  Construction,
#      FLOOR,                    !- Name
#      C5 - 4 IN HW CONCRETE;    !- Outside Layer
#  ,
#  Construction,
#      ROOF31,                   !- Name
#      R31LAYER;                 !- Outside Layer
#  ], 'CONSTRUCTION:CFACTORUNDERGROUNDWALL': [], 'CONSTRUCTION:FFACTORGROUNDFLOOR': [], 'CONSTRUCTION:INTERNALSOURCE': [], 'WINDOWTHERMALMODEL:PARAMS': [], 'CONSTRUCTION:COMPLEXFENESTRATIONSTATE': [], 'CONSTRUCTION:WINDOWEQUIVALENTLAYER': [], 'CONSTRUCTION:WINDOWDATAFILE': [], 'GLOBALGEOMETRYRULES': [
#  GlobalGeometryRules,
#      UpperLeftCorner,          !- Starting Vertex Position
#      CounterClockWise,         !- Vertex Entry Direction
#      World;                    !- Coordinate System
#  ], 'GEOMETRYTRANSFORM': [], 'ZONE': [
#  Zone,
#      ZONE ONE,                 !- Name
#      0.0,                      !- Direction of Relative North
#      0.0,                      !- X Origin
#      0.0,                      !- Y Origin
#      0.0,                      !- Z Origin
#      1,                        !- Type
#      1,                        !- Multiplier
#      autocalculate,            !- Ceiling Height
#      autocalculate;            !- Volume
#  ], 'ZONELIST': [], 'ZONEGROUP': [], 'BUILDINGSURFACE:DETAILED': [
#  BuildingSurface:Detailed,
#      Zn001:Wall001,            !- Name
#      Wall,                     !- Surface Type
#      R13WALL,                  !- Construction Name
#      ZONE ONE,                 !- Zone Name
#      Outdoors,                 !- Outside Boundary Condition
#      ,                         !- Outside Boundary Condition Object
#      SunExposed,               !- Sun Exposure
#      WindExposed,              !- Wind Exposure
#      0.5,                      !- View Factor to Ground
#      4,                        !- Number of Vertices
#      0.0,                      !- Vertex 1 Xcoordinate
#      0.0,                      !- Vertex 1 Ycoordinate
#      4.572,                    !- Vertex 1 Zcoordinate
#      0.0,                      !- Vertex 2 Xcoordinate
#      0.0,                      !- Vertex 2 Ycoordinate
#      0.0,                      !- Vertex 2 Zcoordinate
#      15.24,                    !- Vertex 3 Xcoordinate
#      0.0,                      !- Vertex 3 Ycoordinate
#      0.0,                      !- Vertex 3 Zcoordinate
#      15.24,                    !- Vertex 4 Xcoordinate
#      0.0,                      !- Vertex 4 Ycoordinate
#      4.572;                    !- Vertex 4 Zcoordinate
#  ,
#  BuildingSurface:Detailed,
#      Zn001:Wall002,            !- Name
#      Wall,                     !- Surface Type
#      R13WALL,                  !- Construction Name
#      ZONE ONE,                 !- Zone Name
#      Outdoors,                 !- Outside Boundary Condition
#      ,                         !- Outside Boundary Condition Object
#      SunExposed,               !- Sun Exposure
#      WindExposed,              !- Wind Exposure
#      0.5,                      !- View Factor to Ground
#      4,                        !- Number of Vertices
#      15.24,                    !- Vertex 1 Xcoordinate
#      0.0,                      !- Vertex 1 Ycoordinate
#      4.572,                    !- Vertex 1 Zcoordinate
#      15.24,                    !- Vertex 2 Xcoordinate
#      0.0,                      !- Vertex 2 Ycoordinate
#      0.0,                      !- Vertex 2 Zcoordinate
#      15.24,                    !- Vertex 3 Xcoordinate
#      15.24,                    !- Vertex 3 Ycoordinate
#      0.0,                      !- Vertex 3 Zcoordinate
#      15.24,                    !- Vertex 4 Xcoordinate
#      15.24,                    !- Vertex 4 Ycoordinate
#      4.572;                    !- Vertex 4 Zcoordinate
#  ,
#  BuildingSurface:Detailed,
#      Zn001:Wall003,            !- Name
#      Wall,                     !- Surface Type
#      R13WALL,                  !- Construction Name
#      ZONE ONE,                 !- Zone Name
#      Outdoors,                 !- Outside Boundary Condition
#      ,                         !- Outside Boundary Condition Object
#      SunExposed,               !- Sun Exposure
#      WindExposed,              !- Wind Exposure
#      0.5,                      !- View Factor to Ground
#      4,                        !- Number of Vertices
#      15.24,                    !- Vertex 1 Xcoordinate
#      15.24,                    !- Vertex 1 Ycoordinate
#      4.572,                    !- Vertex 1 Zcoordinate
#      15.24,                    !- Vertex 2 Xcoordinate
#      15.24,                    !- Vertex 2 Ycoordinate
#      0.0,                      !- Vertex 2 Zcoordinate
#      0.0,                      !- Vertex 3 Xcoordinate
#      15.24,                    !- Vertex 3 Ycoordinate
#      0.0,                      !- Vertex 3 Zcoordinate
#      0.0,                      !- Vertex 4 Xcoordinate
#      15.24,                    !- Vertex 4 Ycoordinate
#      4.572;                    !- Vertex 4 Zcoordinate
#  ,
#  BuildingSurface:Detailed,
#      Zn001:Wall004,            !- Name
#      Wall,                     !- Surface Type
#      R13WALL,                  !- Construction Name
#      ZONE ONE,                 !- Zone Name
#      Outdoors,                 !- Outside Boundary Condition
#      ,                         !- Outside Boundary Condition Object
#      SunExposed,               !- Sun Exposure
#      WindExposed,              !- Wind Exposure
#      0.5,                      !- View Factor to Ground
#      4,                        !- Number of Vertices
#      0.0,                      !- Vertex 1 Xcoordinate
#      15.24,                    !- Vertex 1 Ycoordinate
#      4.572,                    !- Vertex 1 Zcoordinate
#      0.0,                      !- Vertex 2 Xcoordinate
#      15.24,                    !- Vertex 2 Ycoordinate
#      0.0,                      !- Vertex 2 Zcoordinate
#      0.0,                      !- Vertex 3 Xcoordinate
#      0.0,                      !- Vertex 3 Ycoordinate
#      0.0,                      !- Vertex 3 Zcoordinate
#      0.0,                      !- Vertex 4 Xcoordinate
#      0.0,                      !- Vertex 4 Ycoordinate
#      4.572;                    !- Vertex 4 Zcoordinate
#  ,
#  BuildingSurface:Detailed,
#      Zn001:Flr001,             !- Name
#      Floor,                    !- Surface Type
#      FLOOR,                    !- Construction Name
#      ZONE ONE,                 !- Zone Name
#      Adiabatic,                !- Outside Boundary Condition
#      ,                         !- Outside Boundary Condition Object
#      NoSun,                    !- Sun Exposure
#      NoWind,                   !- Wind Exposure
#      1.0,                      !- View Factor to Ground
#      4,                        !- Number of Vertices
#      15.24,                    !- Vertex 1 Xcoordinate
#      0.0,                      !- Vertex 1 Ycoordinate
#      0.0,                      !- Vertex 1 Zcoordinate
#      0.0,                      !- Vertex 2 Xcoordinate
#      0.0,                      !- Vertex 2 Ycoordinate
#      0.0,                      !- Vertex 2 Zcoordinate
#      0.0,                      !- Vertex 3 Xcoordinate
#      15.24,                    !- Vertex 3 Ycoordinate
#      0.0,                      !- Vertex 3 Zcoordinate
#      15.24,                    !- Vertex 4 Xcoordinate
#      15.24,                    !- Vertex 4 Ycoordinate
#      0.0;                      !- Vertex 4 Zcoordinate
#  ,
#  BuildingSurface:Detailed,
#      Zn001:Roof001,            !- Name
#      Roof,                     !- Surface Type
#      ROOF31,                   !- Construction Name
#      ZONE ONE,                 !- Zone Name
#      Outdoors,                 !- Outside Boundary Condition
#      ,                         !- Outside Boundary Condition Object
#      SunExposed,               !- Sun Exposure
#      WindExposed,              !- Wind Exposure
#      0.0,                      !- View Factor to Ground
#      4,                        !- Number of Vertices
#      0.0,                      !- Vertex 1 Xcoordinate
#      15.24,                    !- Vertex 1 Ycoordinate
#      4.572,                    !- Vertex 1 Zcoordinate
#      0.0,                      !- Vertex 2 Xcoordinate
#      0.0,                      !- Vertex 2 Ycoordinate
#      4.572,                    !- Vertex 2 Zcoordinate
#      15.24,                    !- Vertex 3 Xcoordinate
#      0.0,                      !- Vertex 3 Ycoordinate
#      4.572,                    !- Vertex 3 Zcoordinate
#      15.24,                    !- Vertex 4 Xcoordinate
#      15.24,                    !- Vertex 4 Ycoordinate
#      4.572;                    !- Vertex 4 Zcoordinate
#  ], 'WALL:DETAILED': [], 'ROOFCEILING:DETAILED': [], 'FLOOR:DETAILED': [], 'WALL:EXTERIOR': [], 'WALL:ADIABATIC': [], 'WALL:UNDERGROUND': [], 'WALL:INTERZONE': [], 'ROOF': [], 'CEILING:ADIABATIC': [], 'CEILING:INTERZONE': [], 'FLOOR:GROUNDCONTACT': [], 'FLOOR:ADIABATIC': [], 'FLOOR:INTERZONE': [], 'FENESTRATIONSURFACE:DETAILED': [], 'WINDOW': [], 'DOOR': [], 'GLAZEDDOOR': [], 'WINDOW:INTERZONE': [], 'DOOR:INTERZONE': [], 'GLAZEDDOOR:INTERZONE': [], 'WINDOWPROPERTY:SHADINGCONTROL': [], 'WINDOWPROPERTY:FRAMEANDDIVIDER': [], 'WINDOWPROPERTY:AIRFLOWCONTROL': [], 'WINDOWPROPERTY:STORMWINDOW': [], 'INTERNALMASS': [], 'SHADING:SITE': [], 'SHADING:BUILDING': [], 'SHADING:SITE:DETAILED': [], 'SHADING:BUILDING:DETAILED': [], 'SHADING:OVERHANG': [], 'SHADING:OVERHANG:PROJECTION': [], 'SHADING:FIN': [], 'SHADING:FIN:PROJECTION': [], 'SHADING:ZONE:DETAILED': [], 'SHADINGPROPERTY:REFLECTANCE': [], 'SURFACEPROPERTY:HEATTRANSFERALGORITHM': [], 'SURFACEPROPERTY:HEATTRANSFERALGORITHM:MULTIPLESURFACE': [], 'SURFACEPROPERTY:HEATTRANSFERALGORITHM:SURFACELIST': [], 'SURFACEPROPERTY:HEATTRANSFERALGORITHM:CONSTRUCTION': [], 'SURFACEPROPERTY:HEATBALANCESOURCETERM': [], 'SURFACECONTROL:MOVABLEINSULATION': [], 'SURFACEPROPERTY:OTHERSIDECOEFFICIENTS': [], 'SURFACEPROPERTY:OTHERSIDECONDITIONSMODEL': [], 'SURFACEPROPERTY:UNDERWATER': [], 'FOUNDATION:KIVA': [], 'FOUNDATION:KIVA:SETTINGS': [], 'SURFACEPROPERTY:EXPOSEDFOUNDATIONPERIMETER': [], 'SURFACECONVECTIONALGORITHM:INSIDE:ADAPTIVEMODELSELECTIONS': [], 'SURFACECONVECTIONALGORITHM:OUTSIDE:ADAPTIVEMODELSELECTIONS': [], 'SURFACECONVECTIONALGORITHM:INSIDE:USERCURVE': [], 'SURFACECONVECTIONALGORITHM:OUTSIDE:USERCURVE': [], 'SURFACEPROPERTY:CONVECTIONCOEFFICIENTS': [], 'SURFACEPROPERTY:CONVECTIONCOEFFICIENTS:MULTIPLESURFACE': [], 'SURFACEPROPERTIES:VAPORCOEFFICIENTS': [], 'SURFACEPROPERTY:EXTERIORNATURALVENTEDCAVITY': [], 'SURFACEPROPERTY:SOLARINCIDENTINSIDE': [], 'SURFACEPROPERTY:LOCALENVIRONMENT': [], 'ZONEPROPERTY:LOCALENVIRONMENT': [], 'SURFACEPROPERTY:SURROUNDINGSURFACES': [], 'COMPLEXFENESTRATIONPROPERTY:SOLARABSORBEDLAYERS': [], 'ZONEPROPERTY:USERVIEWFACTORS:BYSURFACENAME': [], 'GROUNDHEATTRANSFER:CONTROL': [], 'GROUNDHEATTRANSFER:SLAB:MATERIALS': [], 'GROUNDHEATTRANSFER:SLAB:MATLPROPS': [], 'GROUNDHEATTRANSFER:SLAB:BOUNDCONDS': [], 'GROUNDHEATTRANSFER:SLAB:BLDGPROPS': [], 'GROUNDHEATTRANSFER:SLAB:INSULATION': [], 'GROUNDHEATTRANSFER:SLAB:EQUIVALENTSLAB': [], 'GROUNDHEATTRANSFER:SLAB:AUTOGRID': [], 'GROUNDHEATTRANSFER:SLAB:MANUALGRID': [], 'GROUNDHEATTRANSFER:SLAB:XFACE': [], 'GROUNDHEATTRANSFER:SLAB:YFACE': [], 'GROUNDHEATTRANSFER:SLAB:ZFACE': [], 'GROUNDHEATTRANSFER:BASEMENT:SIMPARAMETERS': [], 'GROUNDHEATTRANSFER:BASEMENT:MATLPROPS': [], 'GROUNDHEATTRANSFER:BASEMENT:INSULATION': [], 'GROUNDHEATTRANSFER:BASEMENT:SURFACEPROPS': [], 'GROUNDHEATTRANSFER:BASEMENT:BLDGDATA': [], 'GROUNDHEATTRANSFER:BASEMENT:INTERIOR': [], 'GROUNDHEATTRANSFER:BASEMENT:COMBLDG': [], 'GROUNDHEATTRANSFER:BASEMENT:EQUIVSLAB': [], 'GROUNDHEATTRANSFER:BASEMENT:EQUIVAUTOGRID': [], 'GROUNDHEATTRANSFER:BASEMENT:AUTOGRID': [], 'GROUNDHEATTRANSFER:BASEMENT:MANUALGRID': [], 'GROUNDHEATTRANSFER:BASEMENT:XFACE': [], 'GROUNDHEATTRANSFER:BASEMENT:YFACE': [], 'GROUNDHEATTRANSFER:BASEMENT:ZFACE': [], 'ROOMAIRMODELTYPE': [], 'ROOMAIR:TEMPERATUREPATTERN:USERDEFINED': [], 'ROOMAIR:TEMPERATUREPATTERN:CONSTANTGRADIENT': [], 'ROOMAIR:TEMPERATUREPATTERN:TWOGRADIENT': [], 'ROOMAIR:TEMPERATUREPATTERN:NONDIMENSIONALHEIGHT': [], 'ROOMAIR:TEMPERATUREPATTERN:SURFACEMAPPING': [], 'ROOMAIR:NODE': [], 'ROOMAIRSETTINGS:ONENODEDISPLACEMENTVENTILATION': [], 'ROOMAIRSETTINGS:THREENODEDISPLACEMENTVENTILATION': [], 'ROOMAIRSETTINGS:CROSSVENTILATION': [], 'ROOMAIRSETTINGS:UNDERFLOORAIRDISTRIBUTIONINTERIOR': [], 'ROOMAIRSETTINGS:UNDERFLOORAIRDISTRIBUTIONEXTERIOR': [], 'ROOMAIR:NODE:AIRFLOWNETWORK': [], 'ROOMAIR:NODE:AIRFLOWNETWORK:ADJACENTSURFACELIST': [], 'ROOMAIR:NODE:AIRFLOWNETWORK:INTERNALGAINS': [], 'ROOMAIR:NODE:AIRFLOWNETWORK:HVACEQUIPMENT': [], 'ROOMAIRSETT ...
#  OtherEquipment,
#      Test 352a,                !- Name
#      None,                     !- Fuel Type
#      ZONE ONE,                 !- Zone or ZoneList Name
#      AlwaysOn,                 !- Schedule Name
#      EquipmentLevel,           !- Design Level Calculation Method
#      352.0,                    !- Design Level
#      ,                         !- Power per Zone Floor Area
#      ,                         !- Power per Person
#      0.0,                      !- Fraction Latent
#      0.0,                      !- Fraction Radiant
#      0.0;                      !- Fraction Lost
#  ,
#  OtherEquipment,
#      Test 352 minus,           !- Name
#      None,                     !- Fuel Type
#      ZONE ONE,                 !- Zone or ZoneList Name
#      AlwaysOn,                 !- Schedule Name
#      EquipmentLevel,           !- Design Level Calculation Method
#      -352.0,                   !- Design Level
#      ,                         !- Power per Zone Floor Area
#      ,                         !- Power per Person
#      0.0,                      !- Fraction Latent
#      0.0,                      !- Fraction Radiant
#      0.0;                      !- Fraction Lost
#  ], 'ELECTRICEQUIPMENT:ITE:AIRCOOLED': [], 'ZONEBASEBOARD:OUTDOORTEMPERATURECONTROLLED': [], 'SWIMMINGPOOL:INDOOR': [], 'ZONECONTAMINANTSOURCEANDSINK:CARBONDIOXIDE': [], 'ZONECONTAMINANTSOURCEANDSINK:GENERIC:CONSTANT': [], 'SURFACECONTAMINANTSOURCEANDSINK:GENERIC:PRESSUREDRIVEN': [], 'ZONECONTAMINANTSOURCEANDSINK:GENERIC:CUTOFFMODEL': [], 'ZONECONTAMINANTSOURCEANDSINK:GENERIC:DECAYSOURCE': [], 'SURFACECONTAMINANTSOURCEANDSINK:GENERIC:BOUNDARYLAYERDIFFUSION': [], 'SURFACECONTAMINANTSOURCEANDSINK:GENERIC:DEPOSITIONVELOCITYSINK': [], 'ZONECONTAMINANTSOURCEANDSINK:GENERIC:DEPOSITIONRATESINK': [], 'DAYLIGHTING:CONTROLS': [], 'DAYLIGHTING:REFERENCEPOINT': [], 'DAYLIGHTING:DELIGHT:COMPLEXFENESTRATION': [], 'DAYLIGHTINGDEVICE:TUBULAR': [], 'DAYLIGHTINGDEVICE:SHELF': [], 'DAYLIGHTINGDEVICE:LIGHTWELL': [], 'OUTPUT:DAYLIGHTFACTORS': [], 'OUTPUT:ILLUMINANCEMAP': [], 'OUTPUTCONTROL:ILLUMINANCEMAP:STYLE': [], 'ZONEINFILTRATION:DESIGNFLOWRATE': [], 'ZONEINFILTRATION:EFFECTIVELEAKAGEAREA': [], 'ZONEINFILTRATION:FLOWCOEFFICIENT': [], 'ZONEVENTILATION:DESIGNFLOWRATE': [], 'ZONEVENTILATION:WINDANDSTACKOPENAREA': [], 'ZONEAIRBALANCE:OUTDOORAIR': [], 'ZONEMIXING': [], 'ZONECROSSMIXING': [], 'ZONEREFRIGERATIONDOORMIXING': [], 'ZONEEARTHTUBE': [], 'ZONECOOLTOWER:SHOWER': [], 'ZONETHERMALCHIMNEY': [], 'AIRFLOWNETWORK:SIMULATIONCONTROL': [], 'AIRFLOWNETWORK:MULTIZONE:ZONE': [], 'AIRFLOWNETWORK:MULTIZONE:SURFACE': [], 'AIRFLOWNETWORK:MULTIZONE:REFERENCECRACKCONDITIONS': [], 'AIRFLOWNETWORK:MULTIZONE:SURFACE:CRACK': [], 'AIRFLOWNETWORK:MULTIZONE:SURFACE:EFFECTIVELEAKAGEAREA': [], 'AIRFLOWNETWORK:MULTIZONE:COMPONENT:DETAILEDOPENING': [], 'AIRFLOWNETWORK:MULTIZONE:COMPONENT:SIMPLEOPENING': [], 'AIRFLOWNETWORK:MULTIZONE:COMPONENT:HORIZONTALOPENING': [], 'AIRFLOWNETWORK:MULTIZONE:COMPONENT:ZONEEXHAUSTFAN': [], 'AIRFLOWNETWORK:MULTIZONE:EXTERNALNODE': [], 'AIRFLOWNETWORK:MULTIZONE:WINDPRESSURECOEFFICIENTARRAY': [], 'AIRFLOWNETWORK:MULTIZONE:WINDPRESSURECOEFFICIENTVALUES': [], 'AIRFLOWNETWORK:ZONECONTROL:PRESSURECONTROLLER': [], 'AIRFLOWNETWORK:DISTRIBUTION:NODE': [], 'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:LEAK': [], 'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:LEAKAGERATIO': [], 'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:DUCT': [], 'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:FAN': [], 'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:COIL': [], 'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:HEATEXCHANGER': [], 'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:TERMINALUNIT': [], 'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:CONSTANTPRESSUREDROP': [], 'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:OUTDOORAIRFLOW': [], 'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:RELIEFAIRFLOW': [], 'AIRFLOWNETWORK:DISTRIBUTION:LINKAGE': [], 'AIRFLOWNETWORK:DISTRIBUTION:DUCTVIEWFACTORS': [], 'AIRFLOWNETWORK:OCCUPANTVENTILATIONCONTROL': [], 'AIRFLOWNETWORK:INTRAZONE:NODE': [], 'AIRFLOWNETWORK:INTRAZONE:LINKAGE': [], 'EXTERIOR:LIGHTS': [
#  Exterior:Lights,
#      ExtLights,                !- Name
#      AlwaysOn,                 !- Schedule Name
#      5250.0,                   !- Design Level
#      AstronomicalClock,        !- Control Option
#      Grounds Lights;           !- EndUse Subcategory
#  ], 'EXTERIOR:FUELEQUIPMENT': [], 'EXTERIOR:WATEREQUIPMENT': [], 'HVACTEMPLATE:THERMOSTAT': [], 'HVACTEMPLATE:ZONE:IDEALLOADSAIRSYSTEM': [], 'HVACTEMPLATE:ZONE:BASEBOARDHEAT': [], 'HVACTEMPLATE:ZONE:FANCOIL': [], 'HVACTEMPLATE:ZONE:PTAC': [], 'HVACTEMPLATE:ZONE:PTHP': [], 'HVACTEMPLATE:ZONE:WATERTOAIRHEATPUMP': [], 'HVACTEMPLATE:ZONE:VRF': [], 'HVACTEMPLATE:ZONE:UNITARY': [], 'HVACTEMPLATE:ZONE:VAV': [], 'HVACTEMPLATE:ZONE:VAV:FANPOWERED': [], 'HVACTEMPLATE:ZONE:VAV:HEATANDCOOL': [], 'HVACTEMPLATE:ZONE:CONSTANTVOLUME': [], 'HVACTEMPLATE:ZONE:DUALDUCT': [], 'HVACTEMPLATE:SYSTEM:VRF': [], 'HVACTEMPLATE:SYSTEM:UNITARY': [], 'HVACTEMPLATE:SYSTEM:UNITARYHEATPUMP:AIRTOAIR': [], 'HVACTEMPLATE:SYSTEM:UNITARYSYSTEM': [], 'HVACTEMPLATE:SYSTEM:VAV': [], 'HVACTEMPLATE:SYSTEM:PACKAGEDVAV': [], 'HVACTEMPLATE:SYSTEM:CONSTANTVOLUME': [], 'HVACTEMPLATE:SYSTEM:DUALDUCT': [], 'HVACTEMPLATE:SYSTEM:DEDICATEDOUTDOORAIR': [], 'HVACTEMPLATE:PLANT:CHILLEDWATERLOOP': [], 'HVACTEMPLATE:PLANT:CHILLER': [], 'HVACTEMPLATE:PLANT:CHILLER:OBJECTREFERENCE': [], 'HVACTEMPLATE:PLANT:TOWER': [], 'HVACTEMPLATE:PLANT:TOWER:OBJECTREFERENCE': [], 'HVACTEMPLATE:PLANT:HOTWATERLOOP': [], 'HVACTEMPLATE:PLANT:BOILER': [], 'HVACTEMPLATE:PLANT:BOILER:OBJECTREFERENCE': [], 'HVACTEMPLATE:PLANT:MIXEDWATERLOOP': [], 'DESIGNSPECIFICATION:OUTDOORAIR': [], 'DESIGNSPECIFICATION:ZONEAIRDISTRIBUTION': [], 'SIZING:PARAMETERS': [], 'SIZING:ZONE': [], 'DESIGNSPECIFICATION:ZONEHVAC:SIZING': [], 'DESIGNSPECIFICATION:AIRTERMINAL:SIZING': [], 'SIZING:SYSTEM': [], 'SIZING:PLANT': [], 'OUTPUTCONTROL:SIZING:STYLE': [], 'ZONECONTROL:HUMIDISTAT': [], 'ZONECONTROL:THERMOSTAT': [], 'ZONECONTROL:THERMOSTAT:OPERATIVETEMPERATURE': [], 'ZONECONTROL:THERMOSTAT:THERMALCOMFORT': [], 'ZONECONTROL:THERMOSTAT:TEMPERATUREANDHUMIDITY': [], 'THERMOSTATSETPOINT:SINGLEHEATING': [], 'THERMOSTATSETPOINT:SINGLECOOLING': [], 'THERMOSTATSETPOINT:SINGLEHEATINGORCOOLING': [], 'THERMOSTATSETPOINT:DUALSETPOINT': [], 'THERMOSTATSETPOINT:THERMALCOMFORT:FANGER:SINGLEHEATING': [], 'THERMOSTATSETPOINT:THERMALCOMFORT:FANGER:SINGLECOOLING': [], 'THERMOSTATSETPOINT:THERMALCOMFORT:FANGER:SINGLEHEATINGORCOOLING': [], 'THERMOSTATSETPOINT:THERMALCOMFORT:FANGER:DUALSETPOINT': [], 'ZONECONTROL:THERMOSTAT:STAGEDDUALSETPOINT': [], 'ZONECONTROL:CONTAMINANTCONTROLLER': [], 'ZONEHVAC:IDEALLOADSAIRSYSTEM': [], 'ZONEHVAC:FOURPIPEFANCOIL': [], 'ZONEHVAC:WINDOWAIRCONDITIONER': [], 'ZONEHVAC:PACKAGEDTERMINALAIRCONDITIONER': [], 'ZONEHVAC:PACKAGEDTERMINALHEATPUMP': [], 'ZONEHVAC:WATERTOAIRHEATPUMP': [], 'ZONEHVAC:DEHUMIDIFIER:DX': [], 'ZONEHVAC:ENERGYRECOVERYVENTILATOR': [], 'ZONEHVAC:ENERGYRECOVERYVENTILATOR:CONTROLLER': [], 'ZONEHVAC:UNITVENTILATOR': [], 'ZONEHVAC:UNITHEATER': [], 'ZONEHVAC:EVAPORATIVECOOLERUNIT': [], 'ZONEHVAC:HYBRIDUNITARYHVAC': [], 'ZONEHVAC:OUTDOORAIRUNIT': [], 'ZONEHVAC:OUTDOORAIRUNIT:EQUIPMENTLIST': [], 'ZONEHVAC:TERMINALUNIT:VARIABLEREFRIGERANTFLOW': [], 'ZONEHVAC:BASEBOARD:RADIANTCONVECTIVE:WATER': [], 'ZONEHVAC:BASEBOARD:RADIANTCONVECTIVE:STEAM': [], 'ZONEHVAC:BASEBOARD:RADIANTCONVECTIVE:ELECTRIC': [], 'ZONEHVAC:COOLINGPANEL:RADIANTCONVECTIVE:WATER': [], 'ZONEHVAC:BASEBOARD:CONVECTIVE:WATER': [], 'ZONEHVAC:BASEBOARD:CONVECTIVE:ELECTRIC': [], 'ZONEHVAC:LOWTEMPERATURERADIANT:VARIABLEFLOW': [], 'ZONEHVAC:LOWTEMPERATURERADIANT:CONSTANTFLOW': [], 'ZONEHVAC:LOWTEMPERATURERADIANT:ELECTRIC': [], 'ZONEHVAC:LOWTEMPERATURERADIANT:SURFACEGROUP': [], 'ZONEHVAC:HIGHTEMPERATURERADIANT': [], 'ZONEHVAC:VENTILATEDSLAB': [], 'ZONEHVAC:VENTILATEDSLAB:SLABGROUP': [], 'AIRTERMINAL:SINGLEDUCT:UNCONTROLLED': [], 'AIRTERMINAL:SINGLEDUCT:CONSTANTVOLUME:REHEAT': [], 'AIRTERMINAL:SINGLEDUCT:CONSTANTVOLUME:NOREHEAT': [], 'AIRTERMINAL:SINGLEDUCT:VAV:NOREHEAT': [], 'AIRTERMINAL:SINGLEDUCT:VAV:REHEAT': [], 'AIRTERMINAL:SINGLEDUCT:VAV:REHEAT:VARIABLESPEEDFAN': [], 'AIRTERMINAL:SINGLEDUCT:VAV:HEATANDCOOL:NOREHEAT': [], 'AIRTERMINAL:SINGLEDUCT:VAV:HEATANDCOOL:REHEAT': [], 'AIRTERMINAL:SINGLEDUCT:SERIESPIU:REHEAT': [], 'AIRTERMINAL:SINGLEDUCT:PARALLELPI ...
#  Output:VariableDictionary,
#      IDF;                      !- Key Field
#  ], 'OUTPUT:SURFACES:LIST': [], 'OUTPUT:SURFACES:DRAWING': [
#  Output:Surfaces:Drawing,
#      dxf:wireframe;            !- Report Type
#  ], 'OUTPUT:SCHEDULES': [], 'OUTPUT:CONSTRUCTIONS': [
#  Output:Constructions,
#      Constructions;            !- Details Type 1
#  ], 'OUTPUT:ENERGYMANAGEMENTSYSTEM': [], 'OUTPUTCONTROL:SURFACECOLORSCHEME': [], 'OUTPUT:TABLE:SUMMARYREPORTS': [
#  Output:Table:SummaryReports,
#      AllSummary;               !- Report 1 Name
#  ], 'OUTPUT:TABLE:TIMEBINS': [], 'OUTPUT:TABLE:MONTHLY': [], 'OUTPUT:TABLE:ANNUAL': [], 'OUTPUTCONTROL:TABLE:STYLE': [
#  OutputControl:Table:Style,
#      ALL;                      !- Column Separator
#  ], 'OUTPUTCONTROL:REPORTINGTOLERANCES': [], 'OUTPUT:VARIABLE': [
#  Output:Variable,
#      *,                        !- Key Value
#      Site Outdoor Air Drybulb Temperature,    !- Variable Name
#      hourly;                   !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Daylight Saving Time Status,    !- Variable Name
#      daily;                    !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Day Type Index,      !- Variable Name
#      daily;                    !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Zone Mean Air Temperature,    !- Variable Name
#      hourly;                   !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Zone Total Internal Latent Gain Energy,    !- Variable Name
#      hourly;                   !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Zone Mean Radiant Temperature,    !- Variable Name
#      hourly;                   !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Zone Air Heat Balance Surface Convection Rate,    !- Variable Name
#      hourly;                   !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Zone Air Heat Balance Air Energy Storage Rate,    !- Variable Name
#      hourly;                   !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Surface Inside Face Temperature,    !- Variable Name
#      daily;                    !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Surface Outside Face Temperature,    !- Variable Name
#      daily;                    !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Surface Inside Face Convection Heat Transfer Coefficient,    !- Variable Name
#      daily;                    !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Surface Outside Face Convection Heat Transfer Coefficient,    !- Variable Name
#      daily;                    !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Other Equipment Total Heating Energy,    !- Variable Name
#      monthly;                  !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Zone Other Equipment Total Heating Energy,    !- Variable Name
#      monthly;                  !- Reporting Frequency
#  ], 'OUTPUT:METER': [], 'OUTPUT:METER:METERFILEONLY': [
#  Output:Meter:MeterFileOnly,
#      ExteriorLights:Electricity,    !- Key Name
#      hourly;                   !- Reporting Frequency
#  ,
#  Output:Meter:MeterFileOnly,
#      EnergyTransfer:Building,    !- Key Name
#      hourly;                   !- Reporting Frequency
#  ,
#  Output:Meter:MeterFileOnly,
#      EnergyTransfer:Facility,    !- Key Name
#      hourly;                   !- Reporting Frequency
#  ], 'OUTPUT:METER:CUMULATIVE': [], 'OUTPUT:METER:CUMULATIVE:METERFILEONLY': [], 'METER:CUSTOM': [], 'METER:CUSTOMDECREMENT': [], 'OUTPUT:SQLITE': [], 'OUTPUT:ENVIRONMENTALIMPACTFACTORS': [], 'ENVIRONMENTALIMPACTFACTORS': [], 'FUELFACTORS': [], 'OUTPUT:DIAGNOSTICS': [], 'OUTPUT:DEBUGGINGDATA': [], 'OUTPUT:PREPROCESSORMESSAGE': []}

# %% [markdown]
# ## Inspect the idf object

# %% [markdown]
# ### Number of 'idfobjects'

# %%
len(idf.idfobjects)
# Out:
# 799

# %% [markdown]
# ### Count of 'idfobjects'

# %%
{k:len(v) for k,v in idf.idfobjects.items()}
# Out:
# {'VERSION': 1,
#  'SIMULATIONCONTROL': 1,
#  'BUILDING': 1,
#  'SHADOWCALCULATION': 0,
#  'SURFACECONVECTIONALGORITHM:INSIDE': 1,
#  'SURFACECONVECTIONALGORITHM:OUTSIDE': 1,
#  'HEATBALANCEALGORITHM': 1,
#  'HEATBALANCESETTINGS:CONDUCTIONFINITEDIFFERENCE': 0,
#  'ZONEAIRHEATBALANCEALGORITHM': 0,
#  'ZONEAIRCONTAMINANTBALANCE': 0,
#  'ZONEAIRMASSFLOWCONSERVATION': 0,
#  'ZONECAPACITANCEMULTIPLIER:RESEARCHSPECIAL': 0,
#  'TIMESTEP': 1,
#  'CONVERGENCELIMITS': 0,
#  'HVACSYSTEMROOTFINDINGALGORITHM': 0,
#  'COMPLIANCE:BUILDING': 0,
#  'SITE:LOCATION': 1,
#  'SITE:VARIABLELOCATION': 0,
#  'SIZINGPERIOD:DESIGNDAY': 2,
#  'SIZINGPERIOD:WEATHERFILEDAYS': 0,
#  'SIZINGPERIOD:WEATHERFILECONDITIONTYPE': 0,
#  'RUNPERIOD': 1,
#  'RUNPERIOD:CUSTOMRANGE': 0,
#  'RUNPERIODCONTROL:SPECIALDAYS': 0,
#  'RUNPERIODCONTROL:DAYLIGHTSAVINGTIME': 0,
#  'WEATHERPROPERTY:SKYTEMPERATURE': 0,
#  'SITE:WEATHERSTATION': 0,
#  'SITE:HEIGHTVARIATION': 0,
#  'SITE:GROUNDTEMPERATURE:BUILDINGSURFACE': 0,
#  'SITE:GROUNDTEMPERATURE:FCFACTORMETHOD': 0,
#  'SITE:GROUNDTEMPERATURE:SHALLOW': 0,
#  'SITE:GROUNDTEMPERATURE:DEEP': 0,
#  'SITE:GROUNDTEMPERATURE:UNDISTURBED:FINITEDIFFERENCE': 0,
#  'SITE:GROUNDTEMPERATURE:UNDISTURBED:KUSUDAACHENBACH': 0,
#  'SITE:GROUNDTEMPERATURE:UNDISTURBED:XING': 0,
#  'SITE:GROUNDDOMAIN:SLAB': 0,
#  'SITE:GROUNDDOMAIN:BASEMENT': 0,
#  'SITE:GROUNDREFLECTANCE': 0,
#  'SITE:GROUNDREFLECTANCE:SNOWMODIFIER': 0,
#  'SITE:WATERMAINSTEMPERATURE': 0,
#  'SITE:PRECIPITATION': 0,
#  'ROOFIRRIGATION': 0,
#  'SITE:SOLARANDVISIBLESPECTRUM': 0,
#  'SITE:SPECTRUMDATA': 0,
#  'SCHEDULETYPELIMITS': 2,
#  'SCHEDULE:DAY:HOURLY': 0,
#  'SCHEDULE:DAY:INTERVAL': 0,
#  'SCHEDULE:DAY:LIST': 0,
#  'SCHEDULE:WEEK:DAILY': 0,
#  'SCHEDULE:WEEK:COMPACT': 0,
#  'SCHEDULE:YEAR': 0,
#  'SCHEDULE:COMPACT': 0,
#  'SCHEDULE:CONSTANT': 1,
#  'SCHEDULE:FILE:SHADING': 0,
#  'SCHEDULE:FILE': 0,
#  'MATERIAL': 1,
#  'MATERIAL:NOMASS': 2,
#  'MATERIAL:INFRAREDTRANSPARENT': 0,
#  'MATERIAL:AIRGAP': 0,
#  'MATERIAL:ROOFVEGETATION': 0,
#  'WINDOWMATERIAL:SIMPLEGLAZINGSYSTEM': 0,
#  'WINDOWMATERIAL:GLAZING': 0,
#  'WINDOWMATERIAL:GLAZINGGROUP:THERMOCHROMIC': 0,
#  'WINDOWMATERIAL:GLAZING:REFRACTIONEXTINCTIONMETHOD': 0,
#  'WINDOWMATERIAL:GAS': 0,
#  'WINDOWGAP:SUPPORTPILLAR': 0,
#  'WINDOWGAP:DEFLECTIONSTATE': 0,
#  'WINDOWMATERIAL:GASMIXTURE': 0,
#  'WINDOWMATERIAL:GAP': 0,
#  'WINDOWMATERIAL:SHADE': 0,
#  'WINDOWMATERIAL:COMPLEXSHADE': 0,
#  'WINDOWMATERIAL:BLIND': 0,
#  'WINDOWMATERIAL:SCREEN': 0,
#  'WINDOWMATERIAL:SHADE:EQUIVALENTLAYER': 0,
#  'WINDOWMATERIAL:DRAPE:EQUIVALENTLAYER': 0,
#  'WINDOWMATERIAL:BLIND:EQUIVALENTLAYER': 0,
#  'WINDOWMATERIAL:SCREEN:EQUIVALENTLAYER': 0,
#  'WINDOWMATERIAL:GLAZING:EQUIVALENTLAYER': 0,
#  'WINDOWMATERIAL:GAP:EQUIVALENTLAYER': 0,
#  'MATERIALPROPERTY:MOISTUREPENETRATIONDEPTH:SETTINGS': 0,
#  'MATERIALPROPERTY:PHASECHANGE': 0,
#  'MATERIALPROPERTY:PHASECHANGEHYSTERESIS': 0,
#  'MATERIALPROPERTY:VARIABLETHERMALCONDUCTIVITY': 0,
#  'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:SETTINGS': 0,
#  'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:SORPTIONISOTHERM': 0,
#  'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:SUCTION': 0,
#  'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:REDISTRIBUTION': 0,
#  'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:DIFFUSION': 0,
#  'MATERIALPROPERTY:HEATANDMOISTURETRANSFER:THERMALCONDUCTIVITY': 0,
#  'MATERIALPROPERTY:GLAZINGSPECTRALDATA': 0,
#  'CONSTRUCTION': 3,
#  'CONSTRUCTION:CFACTORUNDERGROUNDWALL': 0,
#  'CONSTRUCTION:FFACTORGROUNDFLOOR': 0,
#  'CONSTRUCTION:INTERNALSOURCE': 0,
#  'WINDOWTHERMALMODEL:PARAMS': 0,
#  'CONSTRUCTION:COMPLEXFENESTRATIONSTATE': 0,
#  'CONSTRUCTION:WINDOWEQUIVALENTLAYER': 0,
#  'CONSTRUCTION:WINDOWDATAFILE': 0,
#  'GLOBALGEOMETRYRULES': 1,
#  'GEOMETRYTRANSFORM': 0,
#  'ZONE': 1,
#  'ZONELIST': 0,
#  'ZONEGROUP': 0,
#  'BUILDINGSURFACE:DETAILED': 6,
#  'WALL:DETAILED': 0,
#  'ROOFCEILING:DETAILED': 0,
#  'FLOOR:DETAILED': 0,
#  'WALL:EXTERIOR': 0,
#  'WALL:ADIABATIC': 0,
#  'WALL:UNDERGROUND': 0,
#  'WALL:INTERZONE': 0,
#  'ROOF': 0,
#  'CEILING:ADIABATIC': 0,
#  'CEILING:INTERZONE': 0,
#  'FLOOR:GROUNDCONTACT': 0,
#  'FLOOR:ADIABATIC': 0,
#  'FLOOR:INTERZONE': 0,
#  'FENESTRATIONSURFACE:DETAILED': 0,
#  'WINDOW': 0,
#  'DOOR': 0,
#  'GLAZEDDOOR': 0,
#  'WINDOW:INTERZONE': 0,
#  'DOOR:INTERZONE': 0,
#  'GLAZEDDOOR:INTERZONE': 0,
#  'WINDOWPROPERTY:SHADINGCONTROL': 0,
#  'WINDOWPROPERTY:FRAMEANDDIVIDER': 0,
#  'WINDOWPROPERTY:AIRFLOWCONTROL': 0,
#  'WINDOWPROPERTY:STORMWINDOW': 0,
#  'INTERNALMASS': 0,
#  'SHADING:SITE': 0,
#  'SHADING:BUILDING': 0,
#  'SHADING:SITE:DETAILED': 0,
#  'SHADING:BUILDING:DETAILED': 0,
#  'SHADING:OVERHANG': 0,
#  'SHADING:OVERHANG:PROJECTION': 0,
#  'SHADING:FIN': 0,
#  'SHADING:FIN:PROJECTION': 0,
#  'SHADING:ZONE:DETAILED': 0,
#  'SHADINGPROPERTY:REFLECTANCE': 0,
#  'SURFACEPROPERTY:HEATTRANSFERALGORITHM': 0,
#  'SURFACEPROPERTY:HEATTRANSFERALGORITHM:MULTIPLESURFACE': 0,
#  'SURFACEPROPERTY:HEATTRANSFERALGORITHM:SURFACELIST': 0,
#  'SURFACEPROPERTY:HEATTRANSFERALGORITHM:CONSTRUCTION': 0,
#  'SURFACEPROPERTY:HEATBALANCESOURCETERM': 0,
#  'SURFACECONTROL:MOVABLEINSULATION': 0,
#  'SURFACEPROPERTY:OTHERSIDECOEFFICIENTS': 0,
#  'SURFACEPROPERTY:OTHERSIDECONDITIONSMODEL': 0,
#  'SURFACEPROPERTY:UNDERWATER': 0,
#  'FOUNDATION:KIVA': 0,
#  'FOUNDATION:KIVA:SETTINGS': 0,
#  'SURFACEPROPERTY:EXPOSEDFOUNDATIONPERIMETER': 0,
#  'SURFACECONVECTIONALGORITHM:INSIDE:ADAPTIVEMODELSELECTIONS': 0,
#  'SURFACECONVECTIONALGORITHM:OUTSIDE:ADAPTIVEMODELSELECTIONS': 0,
#  'SURFACECONVECTIONALGORITHM:INSIDE:USERCURVE': 0,
#  'SURFACECONVECTIONALGORITHM:OUTSIDE:USERCURVE': 0,
#  'SURFACEPROPERTY:CONVECTIONCOEFFICIENTS': 0,
#  'SURFACEPROPERTY:CONVECTIONCOEFFICIENTS:MULTIPLESURFACE': 0,
#  'SURFACEPROPERTIES:VAPORCOEFFICIENTS': 0,
#  'SURFACEPROPERTY:EXTERIORNATURALVENTEDCAVITY': 0,
#  'SURFACEPROPERTY:SOLARINCIDENTINSIDE': 0,
#  'SURFACEPROPERTY:LOCALENVIRONMENT': 0,
#  'ZONEPROPERTY:LOCALENVIRONMENT': 0,
#  'SURFACEPROPERTY:SURROUNDINGSURFACES': 0,
#  'COMPLEXFENESTRATIONPROPERTY:SOLARABSORBEDLAYERS': 0,
#  'ZONEPROPERTY:USERVIEWFACTORS:BYSURFACENAME': 0,
#  'GROUNDHEATTRANSFER:CONTROL': 0,
#  'GROUNDHEATTRANSFER:SLAB:MATERIALS': 0,
#  'GROUNDHEATTRANSFER:SLAB:MATLPROPS': 0,
#  'GROUNDHEATTRANSFER:SLAB:BOUNDCONDS': 0,
#  'GROUNDHEATTRANSFER:SLAB:BLDGPROPS': 0,
#  'GROUNDHEATTRANSFER:SLAB:INSULATION': 0,
#  'GROUNDHEATTRANSFER:SLAB:EQUIVALENTSLAB': 0,
#  'GROUNDHEATTRANSFER:SLAB:AUTOGRID': 0,
#  'GROUNDHEATTRANSFER:SLAB:MANUALGRID': 0,
#  'GROUNDHEATTRANSFER:SLAB:XFACE': 0,
#  'GROUNDHEATTRANSFER:SLAB:YFACE': 0,
#  'GROUNDHEATTRANSFER:SLAB:ZFACE': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:SIMPARAMETERS': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:MATLPROPS': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:INSULATION': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:SURFACEPROPS': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:BLDGDATA': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:INTERIOR': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:COMBLDG': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:EQUIVSLAB': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:EQUIVAUTOGRID': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:AUTOGRID': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:MANUALGRID': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:XFACE': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:YFACE': 0,
#  'GROUNDHEATTRANSFER:BASEMENT:ZFACE': 0,
#  'ROOMAIRMODELTYPE': 0,
#  'ROOMAIR:TEMPERATUREPATTERN:USERDEFINED': 0,
#  'ROOMAIR:TEMPERATUREPATTERN:CONSTANTGRADIENT': 0,
#  'ROOMAIR:TEMPERATUREPATTERN:TWOGRADIENT': 0,
#  'ROOMAIR:TEMPERATUREPATTERN:NONDIMENSIONALHEIGHT': 0,
#  'ROOMAIR:TEMPERATUREPATTERN:SURFACEMAPPING': 0,
#  'ROOMAIR:NODE': 0,
#  'ROOMAIRSETTINGS:ONENODEDISPLACEMENTVENTILATION': 0,
#  'ROOMAIRSETTINGS:THREENODEDISPLACEMENTVENTILATION': 0,
#  'ROOMAIRSETTINGS:CROSSVENTILATION': 0,
#  'ROOMAIRSETTINGS:UNDERFLOORAIRDISTRIBUTIONINTERIOR': 0,
#  'ROOMAIRSETTINGS:UNDERFLOORAIRDISTRIBUTIONEXTERIOR': 0,
#  'ROOMAIR:NODE:AIRFLOWNETWORK': 0,
#  'ROOMAIR:NODE:AIRFLOWNETWORK:ADJACENTSURFACELIST': 0,
#  'ROOMAIR:NODE:AIRFLOWNETWORK:INTERNALGAINS': 0,
#  'ROOMAIR:NODE:AIRFLOWNETWORK:HVACEQUIPMENT': 0,
#  'ROOMAIRSETTINGS:AIRFLOWNETWORK': 0,
#  'PEOPLE': 0,
#  'COMFORTVIEWFACTORANGLES': 0,
#  'LIGHTS': 0,
#  'ELECTRICEQUIPMENT': 0,
#  'GASEQUIPMENT': 0,
#  'HOTWATEREQUIPMENT': 0,
#  'STEAMEQUIPMENT': 0,
#  'OTHEREQUIPMENT': 2,
#  'ELECTRICEQUIPMENT:ITE:AIRCOOLED': 0,
#  'ZONEBASEBOARD:OUTDOORTEMPERATURECONTROLLED': 0,
#  'SWIMMINGPOOL:INDOOR': 0,
#  'ZONECONTAMINANTSOURCEANDSINK:CARBONDIOXIDE': 0,
#  'ZONECONTAMINANTSOURCEANDSINK:GENERIC:CONSTANT': 0,
#  'SURFACECONTAMINANTSOURCEANDSINK:GENERIC:PRESSUREDRIVEN': 0,
#  'ZONECONTAMINANTSOURCEANDSINK:GENERIC:CUTOFFMODEL': 0,
#  'ZONECONTAMINANTSOURCEANDSINK:GENERIC:DECAYSOURCE': 0,
#  'SURFACECONTAMINANTSOURCEANDSINK:GENERIC:BOUNDARYLAYERDIFFUSION': 0,
#  'SURFACECONTAMINANTSOURCEANDSINK:GENERIC:DEPOSITIONVELOCITYSINK': 0,
#  'ZONECONTAMINANTSOURCEANDSINK:GENERIC:DEPOSITIONRATESINK': 0,
#  'DAYLIGHTING:CONTROLS': 0,
#  'DAYLIGHTING:REFERENCEPOINT': 0,
#  'DAYLIGHTING:DELIGHT:COMPLEXFENESTRATION': 0,
#  'DAYLIGHTINGDEVICE:TUBULAR': 0,
#  'DAYLIGHTINGDEVICE:SHELF': 0,
#  'DAYLIGHTINGDEVICE:LIGHTWELL': 0,
#  'OUTPUT:DAYLIGHTFACTORS': 0,
#  'OUTPUT:ILLUMINANCEMAP': 0,
#  'OUTPUTCONTROL:ILLUMINANCEMAP:STYLE': 0,
#  'ZONEINFILTRATION:DESIGNFLOWRATE': 0,
#  'ZONEINFILTRATION:EFFECTIVELEAKAGEAREA': 0,
#  'ZONEINFILTRATION:FLOWCOEFFICIENT': 0,
#  'ZONEVENTILATION:DESIGNFLOWRATE': 0,
#  'ZONEVENTILATION:WINDANDSTACKOPENAREA': 0,
#  'ZONEAIRBALANCE:OUTDOORAIR': 0,
#  'ZONEMIXING': 0,
#  'ZONECROSSMIXING': 0,
#  'ZONEREFRIGERATIONDOORMIXING': 0,
#  'ZONEEARTHTUBE': 0,
#  'ZONECOOLTOWER:SHOWER': 0,
#  'ZONETHERMALCHIMNEY': 0,
#  'AIRFLOWNETWORK:SIMULATIONCONTROL': 0,
#  'AIRFLOWNETWORK:MULTIZONE:ZONE': 0,
#  'AIRFLOWNETWORK:MULTIZONE:SURFACE': 0,
#  'AIRFLOWNETWORK:MULTIZONE:REFERENCECRACKCONDITIONS': 0,
#  'AIRFLOWNETWORK:MULTIZONE:SURFACE:CRACK': 0,
#  'AIRFLOWNETWORK:MULTIZONE:SURFACE:EFFECTIVELEAKAGEAREA': 0,
#  'AIRFLOWNETWORK:MULTIZONE:COMPONENT:DETAILEDOPENING': 0,
#  'AIRFLOWNETWORK:MULTIZONE:COMPONENT:SIMPLEOPENING': 0,
#  'AIRFLOWNETWORK:MULTIZONE:COMPONENT:HORIZONTALOPENING': 0,
#  'AIRFLOWNETWORK:MULTIZONE:COMPONENT:ZONEEXHAUSTFAN': 0,
#  'AIRFLOWNETWORK:MULTIZONE:EXTERNALNODE': 0,
#  'AIRFLOWNETWORK:MULTIZONE:WINDPRESSURECOEFFICIENTARRAY': 0,
#  'AIRFLOWNETWORK:MULTIZONE:WINDPRESSURECOEFFICIENTVALUES': 0,
#  'AIRFLOWNETWORK:ZONECONTROL:PRESSURECONTROLLER': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:NODE': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:LEAK': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:LEAKAGERATIO': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:DUCT': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:FAN': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:COIL': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:HEATEXCHANGER': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:TERMINALUNIT': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:CONSTANTPRESSUREDROP': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:OUTDOORAIRFLOW': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:COMPONENT:RELIEFAIRFLOW': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:LINKAGE': 0,
#  'AIRFLOWNETWORK:DISTRIBUTION:DUCTVIEWFACTORS': 0,
#  'AIRFLOWNETWORK:OCCUPANTVENTILATIONCONTROL': 0,
#  'AIRFLOWNETWORK:INTRAZONE:NODE': 0,
#  'AIRFLOWNETWORK:INTRAZONE:LINKAGE': 0,
#  'EXTERIOR:LIGHTS': 1,
#  'EXTERIOR:FUELEQUIPMENT': 0,
#  'EXTERIOR:WATEREQUIPMENT': 0,
#  'HVACTEMPLATE:THERMOSTAT': 0,
#  'HVACTEMPLATE:ZONE:IDEALLOADSAIRSYSTEM': 0,
#  'HVACTEMPLATE:ZONE:BASEBOARDHEAT': 0,
#  'HVACTEMPLATE:ZONE:FANCOIL': 0,
#  'HVACTEMPLATE:ZONE:PTAC': 0,
#  'HVACTEMPLATE:ZONE:PTHP': 0,
#  'HVACTEMPLATE:ZONE:WATERTOAIRHEATPUMP': 0,
#  'HVACTEMPLATE:ZONE:VRF': 0,
#  'HVACTEMPLATE:ZONE:UNITARY': 0,
#  'HVACTEMPLATE:ZONE:VAV': 0,
#  'HVACTEMPLATE:ZONE:VAV:FANPOWERED': 0,
#  'HVACTEMPLATE:ZONE:VAV:HEATANDCOOL': 0,
#  'HVACTEMPLATE:ZONE:CONSTANTVOLUME': 0,
#  'HVACTEMPLATE:ZONE:DUALDUCT': 0,
#  'HVACTEMPLATE:SYSTEM:VRF': 0,
#  'HVACTEMPLATE:SYSTEM:UNITARY': 0,
#  'HVACTEMPLATE:SYSTEM:UNITARYHEATPUMP:AIRTOAIR': 0,
#  'HVACTEMPLATE:SYSTEM:UNITARYSYSTEM': 0,
#  'HVACTEMPLATE:SYSTEM:VAV': 0,
#  'HVACTEMPLATE:SYSTEM:PACKAGEDVAV': 0,
#  'HVACTEMPLATE:SYSTEM:CONSTANTVOLUME': 0,
#  'HVACTEMPLATE:SYSTEM:DUALDUCT': 0,
#  'HVACTEMPLATE:SYSTEM:DEDICATEDOUTDOORAIR': 0,
#  'HVACTEMPLATE:PLANT:CHILLEDWATERLOOP': 0,
#  'HVACTEMPLATE:PLANT:CHILLER': 0,
#  'HVACTEMPLATE:PLANT:CHILLER:OBJECTREFERENCE': 0,
#  'HVACTEMPLATE:PLANT:TOWER': 0,
#  'HVACTEMPLATE:PLANT:TOWER:OBJECTREFERENCE': 0,
#  'HVACTEMPLATE:PLANT:HOTWATERLOOP': 0,
#  'HVACTEMPLATE:PLANT:BOILER': 0,
#  'HVACTEMPLATE:PLANT:BOILER:OBJECTREFERENCE': 0,
#  'HVACTEMPLATE:PLANT:MIXEDWATERLOOP': 0,
#  'DESIGNSPECIFICATION:OUTDOORAIR': 0,
#  'DESIGNSPECIFICATION:ZONEAIRDISTRIBUTION': 0,
#  'SIZING:PARAMETERS': 0,
#  'SIZING:ZONE': 0,
#  'DESIGNSPECIFICATION:ZONEHVAC:SIZING': 0,
#  'DESIGNSPECIFICATION:AIRTERMINAL:SIZING': 0,
#  'SIZING:SYSTEM': 0,
#  'SIZING:PLANT': 0,
#  'OUTPUTCONTROL:SIZING:STYLE': 0,
#  'ZONECONTROL:HUMIDISTAT': 0,
#  'ZONECONTROL:THERMOSTAT': 0,
#  'ZONECONTROL:THERMOSTAT:OPERATIVETEMPERATURE': 0,
#  'ZONECONTROL:THERMOSTAT:THERMALCOMFORT': 0,
#  'ZONECONTROL:THERMOSTAT:TEMPERATUREANDHUMIDITY': 0,
#  'THERMOSTATSETPOINT:SINGLEHEATING': 0,
#  'THERMOSTATSETPOINT:SINGLECOOLING': 0,
#  'THERMOSTATSETPOINT:SINGLEHEATINGORCOOLING': 0,
#  'THERMOSTATSETPOINT:DUALSETPOINT': 0,
#  'THERMOSTATSETPOINT:THERMALCOMFORT:FANGER:SINGLEHEATING': 0,
#  'THERMOSTATSETPOINT:THERMALCOMFORT:FANGER:SINGLECOOLING': 0,
#  'THERMOSTATSETPOINT:THERMALCOMFORT:FANGER:SINGLEHEATINGORCOOLING': 0,
#  'THERMOSTATSETPOINT:THERMALCOMFORT:FANGER:DUALSETPOINT': 0,
#  'ZONECONTROL:THERMOSTAT:STAGEDDUALSETPOINT': 0,
#  'ZONECONTROL:CONTAMINANTCONTROLLER': 0,
#  'ZONEHVAC:IDEALLOADSAIRSYSTEM': 0,
#  'ZONEHVAC:FOURPIPEFANCOIL': 0,
#  'ZONEHVAC:WINDOWAIRCONDITIONER': 0,
#  'ZONEHVAC:PACKAGEDTERMINALAIRCONDITIONER': 0,
#  'ZONEHVAC:PACKAGEDTERMINALHEATPUMP': 0,
#  'ZONEHVAC:WATERTOAIRHEATPUMP': 0,
#  'ZONEHVAC:DEHUMIDIFIER:DX': 0,
#  'ZONEHVAC:ENERGYRECOVERYVENTILATOR': 0,
#  'ZONEHVAC:ENERGYRECOVERYVENTILATOR:CONTROLLER': 0,
#  'ZONEHVAC:UNITVENTILATOR': 0,
#  'ZONEHVAC:UNITHEATER': 0,
#  'ZONEHVAC:EVAPORATIVECOOLERUNIT': 0,
#  'ZONEHVAC:HYBRIDUNITARYHVAC': 0,
#  'ZONEHVAC:OUTDOORAIRUNIT': 0,
#  'ZONEHVAC:OUTDOORAIRUNIT:EQUIPMENTLIST': 0,
#  'ZONEHVAC:TERMINALUNIT:VARIABLEREFRIGERANTFLOW': 0,
#  'ZONEHVAC:BASEBOARD:RADIANTCONVECTIVE:WATER': 0,
#  'ZONEHVAC:BASEBOARD:RADIANTCONVECTIVE:STEAM': 0,
#  'ZONEHVAC:BASEBOARD:RADIANTCONVECTIVE:ELECTRIC': 0,
#  'ZONEHVAC:COOLINGPANEL:RADIANTCONVECTIVE:WATER': 0,
#  'ZONEHVAC:BASEBOARD:CONVECTIVE:WATER': 0,
#  'ZONEHVAC:BASEBOARD:CONVECTIVE:ELECTRIC': 0,
#  'ZONEHVAC:LOWTEMPERATURERADIANT:VARIABLEFLOW': 0,
#  'ZONEHVAC:LOWTEMPERATURERADIANT:CONSTANTFLOW': 0,
#  'ZONEHVAC:LOWTEMPERATURERADIANT:ELECTRIC': 0,
#  'ZONEHVAC:LOWTEMPERATURERADIANT:SURFACEGROUP': 0,
#  'ZONEHVAC:HIGHTEMPERATURERADIANT': 0,
#  'ZONEHVAC:VENTILATEDSLAB': 0,
#  'ZONEHVAC:VENTILATEDSLAB:SLABGROUP': 0,
#  'AIRTERMINAL:SINGLEDUCT:UNCONTROLLED': 0,
#  'AIRTERMINAL:SINGLEDUCT:CONSTANTVOLUME:REHEAT': 0,
#  'AIRTERMINAL:SINGLEDUCT:CONSTANTVOLUME:NOREHEAT': 0,
#  'AIRTERMINAL:SINGLEDUCT:VAV:NOREHEAT': 0,
#  'AIRTERMINAL:SINGLEDUCT:VAV:REHEAT': 0,
#  'AIRTERMINAL:SINGLEDUCT:VAV:REHEAT:VARIABLESPEEDFAN': 0,
#  'AIRTERMINAL:SINGLEDUCT:VAV:HEATANDCOOL:NOREHEAT': 0,
#  'AIRTERMINAL:SINGLEDUCT:VAV:HEATANDCOOL:REHEAT': 0,
#  'AIRTERMINAL:SINGLEDUCT:SERIESPIU:REHEAT': 0,
#  'AIRTERMINAL:SINGLEDUCT:PARALLELPIU:REHEAT': 0,
#  'AIRTERMINAL:SINGLEDUCT:CONSTANTVOLUME:FOURPIPEINDUCTION': 0,
#  'AIRTERMINAL:SINGLEDUCT:CONSTANTVOLUME:FOURPIPEBEAM': 0,
#  'AIRTERMINAL:SINGLEDUCT:CONSTANTVOLUME:COOLEDBEAM': 0,
#  'AIRTERMINAL:SINGLEDUCT:MIXER': 0,
#  'AIRTERMINAL:DUALDUCT:CONSTANTVOLUME': 0,
#  'AIRTERMINAL:DUALDUCT:VAV': 0,
#  'AIRTERMINAL:DUALDUCT:VAV:OUTDOORAIR': 0,
#  'ZONEHVAC:AIRDISTRIBUTIONUNIT': 0,
#  'ZONEHVAC:EQUIPMENTLIST': 0,
#  'ZONEHVAC:EQUIPMENTCONNECTIONS': 0,
#  'FAN:SYSTEMMODEL': 0,
#  'FAN:CONSTANTVOLUME': 0,
#  'FAN:VARIABLEVOLUME': 0,
#  'FAN:ONOFF': 0,
#  'FAN:ZONEEXHAUST': 0,
#  'FANPERFORMANCE:NIGHTVENTILATION': 0,
#  'FAN:COMPONENTMODEL': 0,
#  'COIL:COOLING:WATER': 0,
#  'COIL:COOLING:WATER:DETAILEDGEOMETRY': 0,
#  'COIL:COOLING:DX:SINGLESPEED': 0,
#  'COIL:COOLING:DX:TWOSPEED': 0,
#  'COIL:COOLING:DX:MULTISPEED': 0,
#  'COIL:COOLING:DX:VARIABLESPEED': 0,
#  'COIL:COOLING:DX:TWOSTAGEWITHHUMIDITYCONTROLMODE': 0,
#  'COILPERFORMANCE:DX:COOLING': 0,
#  'COIL:COOLING:DX:VARIABLEREFRIGERANTFLOW': 0,
#  'COIL:HEATING:DX:VARIABLEREFRIGERANTFLOW': 0,
#  'COIL:COOLING:DX:VARIABLEREFRIGERANTFLOW:FLUIDTEMPERATURECONTROL': 0,
#  'COIL:HEATING:DX:VARIABLEREFRIGERANTFLOW:FLUIDTEMPERATURECONTROL': 0,
#  'COIL:HEATING:WATER': 0,
#  'COIL:HEATING:STEAM': 0,
#  'COIL:HEATING:ELECTRIC': 0,
#  'COIL:HEATING:ELECTRIC:MULTISTAGE': 0,
#  'COIL:HEATING:FUEL': 0,
#  'COIL:HEATING:GAS:MULTISTAGE': 0,
#  'COIL:HEATING:DESUPERHEATER': 0,
#  'COIL:HEATING:DX:SINGLESPEED': 0,
#  'COIL:HEATING:DX:MULTISPEED': 0,
#  'COIL:HEATING:DX:VARIABLESPEED': 0,
#  'COIL:COOLING:WATERTOAIRHEATPUMP:PARAMETERESTIMATION': 0,
#  'COIL:HEATING:WATERTOAIRHEATPUMP:PARAMETERESTIMATION': 0,
#  'COIL:COOLING:WATERTOAIRHEATPUMP:EQUATIONFIT': 0,
#  'COIL:COOLING:WATERTOAIRHEATPUMP:VARIABLESPEEDEQUATIONFIT': 0,
#  'COIL:HEATING:WATERTOAIRHEATPUMP:EQUATIONFIT': 0,
#  'COIL:HEATING:WATERTOAIRHEATPUMP:VARIABLESPEEDEQUATIONFIT': 0,
#  'COIL:WATERHEATING:AIRTOWATERHEATPUMP:PUMPED': 0,
#  'COIL:WATERHEATING:AIRTOWATERHEATPUMP:WRAPPED': 0,
#  'COIL:WATERHEATING:AIRTOWATERHEATPUMP:VARIABLESPEED': 0,
#  'COIL:WATERHEATING:DESUPERHEATER': 0,
#  'COILSYSTEM:COOLING:DX': 0,
#  'COILSYSTEM:HEATING:DX': 0,
#  'COILSYSTEM:COOLING:WATER:HEATEXCHANGERASSISTED': 0,
#  'COILSYSTEM:COOLING:DX:HEATEXCHANGERASSISTED': 0,
#  'COILSYSTEM:INTEGRATEDHEATPUMP:AIRSOURCE': 0,
#  'COIL:COOLING:DX:SINGLESPEED:THERMALSTORAGE': 0,
#  'EVAPORATIVECOOLER:DIRECT:CELDEKPAD': 0,
#  'EVAPORATIVECOOLER:INDIRECT:CELDEKPAD': 0,
#  'EVAPORATIVECOOLER:INDIRECT:WETCOIL': 0,
#  'EVAPORATIVECOOLER:INDIRECT:RESEARCHSPECIAL': 0,
#  'EVAPORATIVECOOLER:DIRECT:RESEARCHSPECIAL': 0,
#  'HUMIDIFIER:STEAM:ELECTRIC': 0,
#  'HUMIDIFIER:STEAM:GAS': 0,
#  'DEHUMIDIFIER:DESICCANT:NOFANS': 0,
#  'DEHUMIDIFIER:DESICCANT:SYSTEM': 0,
#  'HEATEXCHANGER:AIRTOAIR:FLATPLATE': 0,
#  'HEATEXCHANGER:AIRTOAIR:SENSIBLEANDLATENT': 0,
#  'HEATEXCHANGER:DESICCANT:BALANCEDFLOW': 0,
#  'HEATEXCHANGER:DESICCANT:BALANCEDFLOW:PERFORMANCEDATATYPE1': 0,
#  'AIRLOOPHVAC:UNITARYSYSTEM': 0,
#  'UNITARYSYSTEMPERFORMANCE:MULTISPEED': 0,
#  'AIRLOOPHVAC:UNITARY:FURNACE:HEATONLY': 0,
#  'AIRLOOPHVAC:UNITARY:FURNACE:HEATCOOL': 0,
#  'AIRLOOPHVAC:UNITARYHEATONLY': 0,
#  'AIRLOOPHVAC:UNITARYHEATCOOL': 0,
#  'AIRLOOPHVAC:UNITARYHEATPUMP:AIRTOAIR': 0,
#  'AIRLOOPHVAC:UNITARYHEATPUMP:WATERTOAIR': 0,
#  'AIRLOOPHVAC:UNITARYHEATCOOL:VAVCHANGEOVERBYPASS': 0,
#  'AIRLOOPHVAC:UNITARYHEATPUMP:AIRTOAIR:MULTISPEED': 0,
#  'AIRCONDITIONER:VARIABLEREFRIGERANTFLOW': 0,
#  'AIRCONDITIONER:VARIABLEREFRIGERANTFLOW:FLUIDTEMPERATURECONTROL': 0,
#  'AIRCONDITIONER:VARIABLEREFRIGERANTFLOW:FLUIDTEMPERATURECONTROL:HR': 0,
#  'ZONETERMINALUNITLIST': 0,
#  'CONTROLLER:WATERCOIL': 0,
#  'CONTROLLER:OUTDOORAIR': 0,
#  'CONTROLLER:MECHANICALVENTILATION': 0,
#  'AIRLOOPHVAC:CONTROLLERLIST': 0,
#  'AIRLOOPHVAC': 0,
#  'AIRLOOPHVAC:OUTDOORAIRSYSTEM:EQUIPMENTLIST': 0,
#  'AIRLOOPHVAC:OUTDOORAIRSYSTEM': 0,
#  'OUTDOORAIR:MIXER': 0,
#  'AIRLOOPHVAC:ZONESPLITTER': 0,
#  'AIRLOOPHVAC:SUPPLYPLENUM': 0,
#  'AIRLOOPHVAC:SUPPLYPATH': 0,
#  'AIRLOOPHVAC:ZONEMIXER': 0,
#  'AIRLOOPHVAC:RETURNPLENUM': 0,
#  'AIRLOOPHVAC:RETURNPATH': 0,
#  'BRANCH': 0,
#  'BRANCHLIST': 0,
#  'CONNECTOR:SPLITTER': 0,
#  'CONNECTOR:MIXER': 0,
#  'CONNECTORLIST': 0,
#  'NODELIST': 0,
#  'OUTDOORAIR:NODE': 0,
#  'OUTDOORAIR:NODELIST': 0,
#  'PIPE:ADIABATIC': 0,
#  'PIPE:ADIABATIC:STEAM': 0,
#  'PIPE:INDOOR': 0,
#  'PIPE:OUTDOOR': 0,
#  'PIPE:UNDERGROUND': 0,
#  'PIPINGSYSTEM:UNDERGROUND:DOMAIN': 0,
#  'PIPINGSYSTEM:UNDERGROUND:PIPECIRCUIT': 0,
#  'PIPINGSYSTEM:UNDERGROUND:PIPESEGMENT': 0,
#  'DUCT': 0,
#  'PUMP:VARIABLESPEED': 0,
#  'PUMP:CONSTANTSPEED': 0,
#  'PUMP:VARIABLESPEED:CONDENSATE': 0,
#  'HEADEREDPUMPS:CONSTANTSPEED': 0,
#  'HEADEREDPUMPS:VARIABLESPEED': 0,
#  'TEMPERINGVALVE': 0,
#  'LOADPROFILE:PLANT': 0,
#  'SOLARCOLLECTORPERFORMANCE:FLATPLATE': 0,
#  'SOLARCOLLECTOR:FLATPLATE:WATER': 0,
#  'SOLARCOLLECTOR:FLATPLATE:PHOTOVOLTAICTHERMAL': 0,
#  'SOLARCOLLECTORPERFORMANCE:PHOTOVOLTAICTHERMAL:SIMPLE': 0,
#  'SOLARCOLLECTOR:INTEGRALCOLLECTORSTORAGE': 0,
#  'SOLARCOLLECTORPERFORMANCE:INTEGRALCOLLECTORSTORAGE': 0,
#  'SOLARCOLLECTOR:UNGLAZEDTRANSPIRED': 0,
#  'SOLARCOLLECTOR:UNGLAZEDTRANSPIRED:MULTISYSTEM': 0,
#  'BOILER:HOTWATER': 0,
#  'BOILER:STEAM': 0,
#  'CHILLER:ELECTRIC:EIR': 0,
#  'CHILLER:ELECTRIC:REFORMULATEDEIR': 0,
#  'CHILLER:ELECTRIC': 0,
#  'CHILLER:ABSORPTION:INDIRECT': 0,
#  'CHILLER:ABSORPTION': 0,
#  'CHILLER:CONSTANTCOP': 0,
#  'CHILLER:ENGINEDRIVEN': 0,
#  'CHILLER:COMBUSTIONTURBINE': 0,
#  'CHILLERHEATER:ABSORPTION:DIRECTFIRED': 0,
#  'CHILLERHEATER:ABSORPTION:DOUBLEEFFECT': 0,
#  'HEATPUMP:WATERTOWATER:EQUATIONFIT:HEATING': 0,
#  'HEATPUMP:WATERTOWATER:EQUATIONFIT:COOLING': 0,
#  'HEATPUMP:WATERTOWATER:PARAMETERESTIMATION:COOLING': 0,
#  'HEATPUMP:WATERTOWATER:PARAMETERESTIMATION:HEATING': 0,
#  'DISTRICTCOOLING': 0,
#  'DISTRICTHEATING': 0,
#  'PLANTCOMPONENT:TEMPERATURESOURCE': 0,
#  'CENTRALHEATPUMPSYSTEM': 0,
#  'CHILLERHEATERPERFORMANCE:ELECTRIC:EIR': 0,
#  'COOLINGTOWER:SINGLESPEED': 0,
#  'COOLINGTOWER:TWOSPEED': 0,
#  'COOLINGTOWER:VARIABLESPEED:MERKEL': 0,
#  'COOLINGTOWER:VARIABLESPEED': 0,
#  'COOLINGTOWERPERFORMANCE:COOLTOOLS': 0,
#  'COOLINGTOWERPERFORMANCE:YORKCALC': 0,
#  'EVAPORATIVEFLUIDCOOLER:SINGLESPEED': 0,
#  'EVAPORATIVEFLUIDCOOLER:TWOSPEED': 0,
#  'FLUIDCOOLER:SINGLESPEED': 0,
#  'FLUIDCOOLER:TWOSPEED': 0,
#  'GROUNDHEATEXCHANGER:SYSTEM': 0,
#  'GROUNDHEATEXCHANGER:VERTICAL:PROPERTIES': 0,
#  'GROUNDHEATEXCHANGER:VERTICAL:ARRAY': 0,
#  'GROUNDHEATEXCHANGER:VERTICAL:SINGLE': 0,
#  'GROUNDHEATEXCHANGER:RESPONSEFACTORS': 0,
#  'GROUNDHEATEXCHANGER:POND': 0,
#  'GROUNDHEATEXCHANGER:SURFACE': 0,
#  'GROUNDHEATEXCHANGER:HORIZONTALTRENCH': 0,
#  'GROUNDHEATEXCHANGER:SLINKY': 0,
#  'HEATEXCHANGER:FLUIDTOFLUID': 0,
#  'WATERHEATER:MIXED': 0,
#  'WATERHEATER:STRATIFIED': 0,
#  'WATERHEATER:SIZING': 0,
#  'WATERHEATER:HEATPUMP:PUMPEDCONDENSER': 0,
#  'WATERHEATER:HEATPUMP:WRAPPEDCONDENSER': 0,
#  'THERMALSTORAGE:ICE:SIMPLE': 0,
#  'THERMALSTORAGE:ICE:DETAILED': 0,
#  'THERMALSTORAGE:CHILLEDWATER:MIXED': 0,
#  'THERMALSTORAGE:CHILLEDWATER:STRATIFIED': 0,
#  'PLANTLOOP': 0,
#  'CONDENSERLOOP': 0,
#  'PLANTEQUIPMENTLIST': 0,
#  'CONDENSEREQUIPMENTLIST': 0,
#  'PLANTEQUIPMENTOPERATION:UNCONTROLLED': 0,
#  'PLANTEQUIPMENTOPERATION:COOLINGLOAD': 0,
#  'PLANTEQUIPMENTOPERATION:HEATINGLOAD': 0,
#  'PLANTEQUIPMENTOPERATION:OUTDOORDRYBULB': 0,
#  'PLANTEQUIPMENTOPERATION:OUTDOORWETBULB': 0,
#  'PLANTEQUIPMENTOPERATION:OUTDOORRELATIVEHUMIDITY': 0,
#  'PLANTEQUIPMENTOPERATION:OUTDOORDEWPOINT': 0,
#  'PLANTEQUIPMENTOPERATION:COMPONENTSETPOINT': 0,
#  'PLANTEQUIPMENTOPERATION:THERMALENERGYSTORAGE': 0,
#  'PLANTEQUIPMENTOPERATION:OUTDOORDRYBULBDIFFERENCE': 0,
#  'PLANTEQUIPMENTOPERATION:OUTDOORWETBULBDIFFERENCE': 0,
#  'PLANTEQUIPMENTOPERATION:OUTDOORDEWPOINTDIFFERENCE': 0,
#  'PLANTEQUIPMENTOPERATIONSCHEMES': 0,
#  'CONDENSEREQUIPMENTOPERATIONSCHEMES': 0,
#  'ENERGYMANAGEMENTSYSTEM:SENSOR': 0,
#  'ENERGYMANAGEMENTSYSTEM:ACTUATOR': 0,
#  'ENERGYMANAGEMENTSYSTEM:PROGRAMCALLINGMANAGER': 0,
#  'ENERGYMANAGEMENTSYSTEM:PROGRAM': 0,
#  'ENERGYMANAGEMENTSYSTEM:SUBROUTINE': 0,
#  'ENERGYMANAGEMENTSYSTEM:GLOBALVARIABLE': 0,
#  'ENERGYMANAGEMENTSYSTEM:OUTPUTVARIABLE': 0,
#  'ENERGYMANAGEMENTSYSTEM:METEREDOUTPUTVARIABLE': 0,
#  'ENERGYMANAGEMENTSYSTEM:TRENDVARIABLE': 0,
#  'ENERGYMANAGEMENTSYSTEM:INTERNALVARIABLE': 0,
#  'ENERGYMANAGEMENTSYSTEM:CURVEORTABLEINDEXVARIABLE': 0,
#  'ENERGYMANAGEMENTSYSTEM:CONSTRUCTIONINDEXVARIABLE': 0,
#  'EXTERNALINTERFACE': 0,
#  'EXTERNALINTERFACE:SCHEDULE': 0,
#  'EXTERNALINTERFACE:VARIABLE': 0,
#  'EXTERNALINTERFACE:ACTUATOR': 0,
#  'EXTERNALINTERFACE:FUNCTIONALMOCKUPUNITIMPORT': 0,
#  'EXTERNALINTERFACE:FUNCTIONALMOCKUPUNITIMPORT:FROM:VARIABLE': 0,
#  'EXTERNALINTERFACE:FUNCTIONALMOCKUPUNITIMPORT:TO:SCHEDULE': 0,
#  'EXTERNALINTERFACE:FUNCTIONALMOCKUPUNITIMPORT:TO:ACTUATOR': 0,
#  'EXTERNALINTERFACE:FUNCTIONALMOCKUPUNITIMPORT:TO:VARIABLE': 0,
#  'EXTERNALINTERFACE:FUNCTIONALMOCKUPUNITEXPORT:FROM:VARIABLE': 0,
#  'EXTERNALINTERFACE:FUNCTIONALMOCKUPUNITEXPORT:TO:SCHEDULE': 0,
#  'EXTERNALINTERFACE:FUNCTIONALMOCKUPUNITEXPORT:TO:ACTUATOR': 0,
#  'EXTERNALINTERFACE:FUNCTIONALMOCKUPUNITEXPORT:TO:VARIABLE': 0,
#  'ZONEHVAC:FORCEDAIR:USERDEFINED': 0,
#  'AIRTERMINAL:SINGLEDUCT:USERDEFINED': 0,
#  'COIL:USERDEFINED': 0,
#  'PLANTCOMPONENT:USERDEFINED': 0,
#  'PLANTEQUIPMENTOPERATION:USERDEFINED': 0,
#  'AVAILABILITYMANAGER:SCHEDULED': 0,
#  'AVAILABILITYMANAGER:SCHEDULEDON': 0,
#  'AVAILABILITYMANAGER:SCHEDULEDOFF': 0,
#  'AVAILABILITYMANAGER:OPTIMUMSTART': 0,
#  'AVAILABILITYMANAGER:NIGHTCYCLE': 0,
#  'AVAILABILITYMANAGER:DIFFERENTIALTHERMOSTAT': 0,
#  'AVAILABILITYMANAGER:HIGHTEMPERATURETURNOFF': 0,
#  'AVAILABILITYMANAGER:HIGHTEMPERATURETURNON': 0,
#  'AVAILABILITYMANAGER:LOWTEMPERATURETURNOFF': 0,
#  'AVAILABILITYMANAGER:LOWTEMPERATURETURNON': 0,
#  'AVAILABILITYMANAGER:NIGHTVENTILATION': 0,
#  'AVAILABILITYMANAGER:HYBRIDVENTILATION': 0,
#  'AVAILABILITYMANAGERASSIGNMENTLIST': 0,
#  'SETPOINTMANAGER:SCHEDULED': 0,
#  'SETPOINTMANAGER:SCHEDULED:DUALSETPOINT': 0,
#  'SETPOINTMANAGER:OUTDOORAIRRESET': 0,
#  'SETPOINTMANAGER:SINGLEZONE:REHEAT': 0,
#  'SETPOINTMANAGER:SINGLEZONE:HEATING': 0,
#  'SETPOINTMANAGER:SINGLEZONE:COOLING': 0,
#  'SETPOINTMANAGER:SINGLEZONE:HUMIDITY:MINIMUM': 0,
#  'SETPOINTMANAGER:SINGLEZONE:HUMIDITY:MAXIMUM': 0,
#  'SETPOINTMANAGER:MIXEDAIR': 0,
#  'SETPOINTMANAGER:OUTDOORAIRPRETREAT': 0,
#  'SETPOINTMANAGER:WARMEST': 0,
#  'SETPOINTMANAGER:COLDEST': 0,
#  'SETPOINTMANAGER:RETURNAIRBYPASSFLOW': 0,
#  'SETPOINTMANAGER:WARMESTTEMPERATUREFLOW': 0,
#  'SETPOINTMANAGER:MULTIZONE:HEATING:AVERAGE': 0,
#  'SETPOINTMANAGER:MULTIZONE:COOLING:AVERAGE': 0,
#  'SETPOINTMANAGER:MULTIZONE:MINIMUMHUMIDITY:AVERAGE': 0,
#  'SETPOINTMANAGER:MULTIZONE:MAXIMUMHUMIDITY:AVERAGE': 0,
#  'SETPOINTMANAGER:MULTIZONE:HUMIDITY:MINIMUM': 0,
#  'SETPOINTMANAGER:MULTIZONE:HUMIDITY:MAXIMUM': 0,
#  'SETPOINTMANAGER:FOLLOWOUTDOORAIRTEMPERATURE': 0,
#  'SETPOINTMANAGER:FOLLOWSYSTEMNODETEMPERATURE': 0,
#  'SETPOINTMANAGER:FOLLOWGROUNDTEMPERATURE': 0,
#  'SETPOINTMANAGER:CONDENSERENTERINGRESET': 0,
#  'SETPOINTMANAGER:CONDENSERENTERINGRESET:IDEAL': 0,
#  'SETPOINTMANAGER:SINGLEZONE:ONESTAGECOOLING': 0,
#  'SETPOINTMANAGER:SINGLEZONE:ONESTAGEHEATING': 0,
#  'SETPOINTMANAGER:RETURNTEMPERATURE:CHILLEDWATER': 0,
#  'SETPOINTMANAGER:RETURNTEMPERATURE:HOTWATER': 0,
#  'REFRIGERATION:CASE': 0,
#  'REFRIGERATION:COMPRESSORRACK': 0,
#  'REFRIGERATION:CASEANDWALKINLIST': 0,
#  'REFRIGERATION:CONDENSER:AIRCOOLED': 0,
#  'REFRIGERATION:CONDENSER:EVAPORATIVECOOLED': 0,
#  'REFRIGERATION:CONDENSER:WATERCOOLED': 0,
#  'REFRIGERATION:CONDENSER:CASCADE': 0,
#  'REFRIGERATION:GASCOOLER:AIRCOOLED': 0,
#  'REFRIGERATION:TRANSFERLOADLIST': 0,
#  'REFRIGERATION:SUBCOOLER': 0,
#  'REFRIGERATION:COMPRESSOR': 0,
#  'REFRIGERATION:COMPRESSORLIST': 0,
#  'REFRIGERATION:SYSTEM': 0,
#  'REFRIGERATION:TRANSCRITICALSYSTEM': 0,
#  'REFRIGERATION:SECONDARYSYSTEM': 0,
#  'REFRIGERATION:WALKIN': 0,
#  'REFRIGERATION:AIRCHILLER': 0,
#  'ZONEHVAC:REFRIGERATIONCHILLERSET': 0,
#  'DEMANDMANAGERASSIGNMENTLIST': 0,
#  'DEMANDMANAGER:EXTERIORLIGHTS': 0,
#  'DEMANDMANAGER:LIGHTS': 0,
#  'DEMANDMANAGER:ELECTRICEQUIPMENT': 0,
#  'DEMANDMANAGER:THERMOSTATS': 0,
#  'DEMANDMANAGER:VENTILATION': 0,
#  'GENERATOR:INTERNALCOMBUSTIONENGINE': 0,
#  'GENERATOR:COMBUSTIONTURBINE': 0,
#  'GENERATOR:MICROTURBINE': 0,
#  'GENERATOR:PHOTOVOLTAIC': 0,
#  'PHOTOVOLTAICPERFORMANCE:SIMPLE': 0,
#  'PHOTOVOLTAICPERFORMANCE:EQUIVALENTONE-DIODE': 0,
#  'PHOTOVOLTAICPERFORMANCE:SANDIA': 0,
#  'GENERATOR:PVWATTS': 0,
#  'ELECTRICLOADCENTER:INVERTER:PVWATTS': 0,
#  'GENERATOR:FUELCELL': 0,
#  'GENERATOR:FUELCELL:POWERMODULE': 0,
#  'GENERATOR:FUELCELL:AIRSUPPLY': 0,
#  'GENERATOR:FUELCELL:WATERSUPPLY': 0,
#  'GENERATOR:FUELCELL:AUXILIARYHEATER': 0,
#  'GENERATOR:FUELCELL:EXHAUSTGASTOWATERHEATEXCHANGER': 0,
#  'GENERATOR:FUELCELL:ELECTRICALSTORAGE': 0,
#  'GENERATOR:FUELCELL:INVERTER': 0,
#  'GENERATOR:FUELCELL:STACKCOOLER': 0,
#  'GENERATOR:MICROCHP': 0,
#  'GENERATOR:MICROCHP:NONNORMALIZEDPARAMETERS': 0,
#  'GENERATOR:FUELSUPPLY': 0,
#  'GENERATOR:WINDTURBINE': 0,
#  'ELECTRICLOADCENTER:GENERATORS': 0,
#  'ELECTRICLOADCENTER:INVERTER:SIMPLE': 0,
#  'ELECTRICLOADCENTER:INVERTER:FUNCTIONOFPOWER': 0,
#  'ELECTRICLOADCENTER:INVERTER:LOOKUPTABLE': 0,
#  'ELECTRICLOADCENTER:STORAGE:SIMPLE': 0,
#  'ELECTRICLOADCENTER:STORAGE:BATTERY': 0,
#  'ELECTRICLOADCENTER:TRANSFORMER': 0,
#  'ELECTRICLOADCENTER:DISTRIBUTION': 0,
#  'ELECTRICLOADCENTER:STORAGE:CONVERTER': 0,
#  'WATERUSE:EQUIPMENT': 0,
#  'WATERUSE:CONNECTIONS': 0,
#  'WATERUSE:STORAGE': 0,
#  'WATERUSE:WELL': 0,
#  'WATERUSE:RAINCOLLECTOR': 0,
#  'FAULTMODEL:TEMPERATURESENSOROFFSET:OUTDOORAIR': 0,
#  'FAULTMODEL:HUMIDITYSENSOROFFSET:OUTDOORAIR': 0,
#  'FAULTMODEL:ENTHALPYSENSOROFFSET:OUTDOORAIR': 0,
#  'FAULTMODEL:PRESSURESENSOROFFSET:OUTDOORAIR': 0,
#  'FAULTMODEL:TEMPERATURESENSOROFFSET:RETURNAIR': 0,
#  'FAULTMODEL:ENTHALPYSENSOROFFSET:RETURNAIR': 0,
#  'FAULTMODEL:TEMPERATURESENSOROFFSET:CHILLERSUPPLYWATER': 0,
#  'FAULTMODEL:TEMPERATURESENSOROFFSET:COILSUPPLYAIR': 0,
#  'FAULTMODEL:TEMPERATURESENSOROFFSET:CONDENSERSUPPLYWATER': 0,
#  'FAULTMODEL:THERMOSTATOFFSET': 0,
#  'FAULTMODEL:HUMIDISTATOFFSET': 0,
#  'FAULTMODEL:FOULING:AIRFILTER': 0,
#  'FAULTMODEL:FOULING:BOILER': 0,
#  'FAULTMODEL:FOULING:EVAPORATIVECOOLER': 0,
#  'FAULTMODEL:FOULING:CHILLER': 0,
#  'FAULTMODEL:FOULING:COOLINGTOWER': 0,
#  'FAULTMODEL:FOULING:COIL': 0,
#  'MATRIX:TWODIMENSION': 0,
#  'HYBRIDMODEL:ZONE': 0,
#  'CURVE:LINEAR': 0,
#  'CURVE:QUADLINEAR': 0,
#  'CURVE:QUADRATIC': 0,
#  'CURVE:CUBIC': 0,
#  'CURVE:QUARTIC': 0,
#  'CURVE:EXPONENT': 0,
#  'CURVE:BICUBIC': 0,
#  'CURVE:BIQUADRATIC': 0,
#  'CURVE:QUADRATICLINEAR': 0,
#  'CURVE:CUBICLINEAR': 0,
#  'CURVE:TRIQUADRATIC': 0,
#  'CURVE:FUNCTIONAL:PRESSUREDROP': 0,
#  'CURVE:FANPRESSURERISE': 0,
#  'CURVE:EXPONENTIALSKEWNORMAL': 0,
#  'CURVE:SIGMOID': 0,
#  'CURVE:RECTANGULARHYPERBOLA1': 0,
#  'CURVE:RECTANGULARHYPERBOLA2': 0,
#  'CURVE:EXPONENTIALDECAY': 0,
#  'CURVE:DOUBLEEXPONENTIALDECAY': 0,
#  'CURVE:CHILLERPARTLOADWITHLIFT': 0,
#  'TABLE:ONEINDEPENDENTVARIABLE': 0,
#  'TABLE:TWOINDEPENDENTVARIABLES': 0,
#  'TABLE:MULTIVARIABLELOOKUP': 0,
#  'FLUIDPROPERTIES:NAME': 0,
#  'FLUIDPROPERTIES:GLYCOLCONCENTRATION': 0,
#  'FLUIDPROPERTIES:TEMPERATURES': 0,
#  'FLUIDPROPERTIES:SATURATED': 0,
#  'FLUIDPROPERTIES:SUPERHEATED': 0,
#  'FLUIDPROPERTIES:CONCENTRATION': 0,
#  'CURRENCYTYPE': 0,
#  'COMPONENTCOST:ADJUSTMENTS': 0,
#  'COMPONENTCOST:REFERENCE': 0,
#  'COMPONENTCOST:LINEITEM': 0,
#  'UTILITYCOST:TARIFF': 0,
#  'UTILITYCOST:QUALIFY': 0,
#  'UTILITYCOST:CHARGE:SIMPLE': 0,
#  'UTILITYCOST:CHARGE:BLOCK': 0,
#  'UTILITYCOST:RATCHET': 0,
#  'UTILITYCOST:VARIABLE': 0,
#  'UTILITYCOST:COMPUTATION': 0,
#  'LIFECYCLECOST:PARAMETERS': 0,
#  'LIFECYCLECOST:RECURRINGCOSTS': 0,
#  'LIFECYCLECOST:NONRECURRINGCOST': 0,
#  'LIFECYCLECOST:USEPRICEESCALATION': 0,
#  'LIFECYCLECOST:USEADJUSTMENT': 0,
#  'PARAMETRIC:SETVALUEFORRUN': 0,
#  'PARAMETRIC:LOGIC': 0,
#  'PARAMETRIC:RUNCONTROL': 0,
#  'PARAMETRIC:FILENAMESUFFIX': 0,
#  'OUTPUT:VARIABLEDICTIONARY': 1,
#  'OUTPUT:SURFACES:LIST': 0,
#  'OUTPUT:SURFACES:DRAWING': 1,
#  'OUTPUT:SCHEDULES': 0,
#  'OUTPUT:CONSTRUCTIONS': 1,
#  'OUTPUT:ENERGYMANAGEMENTSYSTEM': 0,
#  'OUTPUTCONTROL:SURFACECOLORSCHEME': 0,
#  'OUTPUT:TABLE:SUMMARYREPORTS': 1,
#  'OUTPUT:TABLE:TIMEBINS': 0,
#  'OUTPUT:TABLE:MONTHLY': 0,
#  'OUTPUT:TABLE:ANNUAL': 0,
#  'OUTPUTCONTROL:TABLE:STYLE': 1,
#  'OUTPUTCONTROL:REPORTINGTOLERANCES': 0,
#  'OUTPUT:VARIABLE': 14,
#  'OUTPUT:METER': 0,
#  'OUTPUT:METER:METERFILEONLY': 3,
#  'OUTPUT:METER:CUMULATIVE': 0,
#  'OUTPUT:METER:CUMULATIVE:METERFILEONLY': 0,
#  'METER:CUSTOM': 0,
#  'METER:CUSTOMDECREMENT': 0,
#  'OUTPUT:SQLITE': 0,
#  'OUTPUT:ENVIRONMENTALIMPACTFACTORS': 0,
#  'ENVIRONMENTALIMPACTFACTORS': 0,
#  'FUELFACTORS': 0,
#  'OUTPUT:DIAGNOSTICS': 0,
#  'OUTPUT:DEBUGGINGDATA': 0,
#  'OUTPUT:PREPROCESSORMESSAGE': 0}

# %% [markdown]
# ### Count of 'idfobjects' that are present

# %%
{k:len(v) for k,v in idf.idfobjects.items() if len(v)>0}
# Out:
# {'VERSION': 1,
#  'SIMULATIONCONTROL': 1,
#  'BUILDING': 1,
#  'SURFACECONVECTIONALGORITHM:INSIDE': 1,
#  'SURFACECONVECTIONALGORITHM:OUTSIDE': 1,
#  'HEATBALANCEALGORITHM': 1,
#  'TIMESTEP': 1,
#  'SITE:LOCATION': 1,
#  'SIZINGPERIOD:DESIGNDAY': 2,
#  'RUNPERIOD': 1,
#  'SCHEDULETYPELIMITS': 2,
#  'SCHEDULE:CONSTANT': 1,
#  'MATERIAL': 1,
#  'MATERIAL:NOMASS': 2,
#  'CONSTRUCTION': 3,
#  'GLOBALGEOMETRYRULES': 1,
#  'ZONE': 1,
#  'BUILDINGSURFACE:DETAILED': 6,
#  'OTHEREQUIPMENT': 2,
#  'EXTERIOR:LIGHTS': 1,
#  'OUTPUT:VARIABLEDICTIONARY': 1,
#  'OUTPUT:SURFACES:DRAWING': 1,
#  'OUTPUT:CONSTRUCTIONS': 1,
#  'OUTPUT:TABLE:SUMMARYREPORTS': 1,
#  'OUTPUTCONTROL:TABLE:STYLE': 1,
#  'OUTPUT:VARIABLE': 14,
#  'OUTPUT:METER:METERFILEONLY': 3}

# %% [markdown]
# ### Print the 'BUILDING' objects

# %%
idf.idfobjects['BUILDING']
# Out:
# [
# Building,
#     Simple One Zone (Wireframe DXF),    !- Name
#     0.0,                      !- North Axis
#     Suburbs,                  !- Terrain
#     0.04,                     !- Loads Convergence Tolerance Value
#     0.004,                    !- Temperature Convergence Tolerance Value
#     MinimalShadowing,         !- Solar Distribution
#     30,                       !- Maximum Number of Warmup Days
#     6;                        !- Minimum Number of Warmup Days
# ]

# %% [markdown]
# ### Print the orientation of the first 'BUILDING' object

# %%
idf.idfobjects['BUILDING'][0].North_Axis
# Out:
# 0.0

# %% [markdown]
# ### Print the 'CONSTRUCTION' objects

# %%
idf.idfobjects['CONSTRUCTION']
# Out:
# [
# Construction,
#     R13WALL,                  !- Name
#     R13LAYER;                 !- Outside Layer
# ,
# Construction,
#     FLOOR,                    !- Name
#     C5 - 4 IN HW CONCRETE;    !- Outside Layer
# ,
# Construction,
#     ROOF31,                   !- Name
#     R31LAYER;                 !- Outside Layer
# ]

# %% [markdown]
# ## epJSON format
#
# Alternatively, it may now be possible to do some this using the epJSON format and not need to use Eppy.
#
# Using the '1ZoneUncontrolled.epJSON' file...

# %%
import json
fp='1ZoneUncontrolled.epJSON'
with open(fp) as f:
    data = json.load(f)
data
# Out:
# {'Building': {'Simple One Zone (Wireframe DXF)': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 8,
#    'idf_order': 3,
#    'loads_convergence_tolerance_value': 0.04,
#    'maximum_number_of_warmup_days': 30,
#    'minimum_number_of_warmup_days': 6,
#    'north_axis': 0,
#    'solar_distribution': 'MinimalShadowing',
#    'temperature_convergence_tolerance_value': 0.004,
#    'terrain': 'Suburbs'}},
#  'BuildingSurface:Detailed': {'Zn001:Flr001': {'construction_name': 'FLOOR',
#    'idf_max_extensible_fields': 12,
#    'idf_max_fields': 22,
#    'idf_order': 25,
#    'number_of_vertices': 4,
#    'outside_boundary_condition': 'Adiabatic',
#    'sun_exposure': 'NoSun',
#    'surface_type': 'Floor',
#    'vertices': [{'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 0.0,
#      'vertex_z_coordinate': 0.0},
#     {'vertex_x_coordinate': 0.0,
#      'vertex_y_coordinate': 0.0,
#      'vertex_z_coordinate': 0.0},
#     {'vertex_x_coordinate': 0.0,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 0.0},
#     {'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 0.0}],
#    'view_factor_to_ground': 1.0,
#    'wind_exposure': 'NoWind',
#    'zone_name': 'ZONE ONE'},
#   'Zn001:Roof001': {'construction_name': 'ROOF31',
#    'idf_max_extensible_fields': 12,
#    'idf_max_fields': 22,
#    'idf_order': 26,
#    'number_of_vertices': 4,
#    'outside_boundary_condition': 'Outdoors',
#    'sun_exposure': 'SunExposed',
#    'surface_type': 'Roof',
#    'vertices': [{'vertex_x_coordinate': 0.0,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 4.572},
#     {'vertex_x_coordinate': 0.0,
#      'vertex_y_coordinate': 0.0,
#      'vertex_z_coordinate': 4.572},
#     {'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 0.0,
#      'vertex_z_coordinate': 4.572},
#     {'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 4.572}],
#    'view_factor_to_ground': 0,
#    'wind_exposure': 'WindExposed',
#    'zone_name': 'ZONE ONE'},
#   'Zn001:Wall001': {'construction_name': 'R13WALL',
#    'idf_max_extensible_fields': 12,
#    'idf_max_fields': 22,
#    'idf_order': 21,
#    'number_of_vertices': 4,
#    'outside_boundary_condition': 'Outdoors',
#    'sun_exposure': 'SunExposed',
#    'surface_type': 'Wall',
#    'vertices': [{'vertex_x_coordinate': 0,
#      'vertex_y_coordinate': 0,
#      'vertex_z_coordinate': 4.572},
#     {'vertex_x_coordinate': 0,
#      'vertex_y_coordinate': 0,
#      'vertex_z_coordinate': 0},
#     {'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 0,
#      'vertex_z_coordinate': 0},
#     {'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 0,
#      'vertex_z_coordinate': 4.572}],
#    'view_factor_to_ground': 0.5,
#    'wind_exposure': 'WindExposed',
#    'zone_name': 'ZONE ONE'},
#   'Zn001:Wall002': {'construction_name': 'R13WALL',
#    'idf_max_extensible_fields': 12,
#    'idf_max_fields': 22,
#    'idf_order': 22,
#    'number_of_vertices': 4,
#    'outside_boundary_condition': 'Outdoors',
#    'sun_exposure': 'SunExposed',
#    'surface_type': 'Wall',
#    'vertices': [{'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 0,
#      'vertex_z_coordinate': 4.572},
#     {'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 0,
#      'vertex_z_coordinate': 0},
#     {'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 0},
#     {'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 4.572}],
#    'view_factor_to_ground': 0.5,
#    'wind_exposure': 'WindExposed',
#    'zone_name': 'ZONE ONE'},
#   'Zn001:Wall003': {'construction_name': 'R13WALL',
#    'idf_max_extensible_fields': 12,
#    'idf_max_fields': 22,
#    'idf_order': 23,
#    'number_of_vertices': 4,
#    'outside_boundary_condition': 'Outdoors',
#    'sun_exposure': 'SunExposed',
#    'surface_type': 'Wall',
#    'vertices': [{'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 4.572},
#     {'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 0},
#     {'vertex_x_coordinate': 0,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 0},
#     {'vertex_x_coordinate': 0,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 4.572}],
#    'view_factor_to_ground': 0.5,
#    'wind_exposure': 'WindExposed',
#    'zone_name': 'ZONE ONE'},
#   'Zn001:Wall004': {'construction_name': 'R13WALL',
#    'idf_max_extensible_fields': 12,
#    'idf_max_fields': 22,
#    'idf_order': 24,
#    'number_of_vertices': 4,
#    'outside_boundary_condition': 'Outdoors',
#    'sun_exposure': 'SunExposed',
#    'surface_type': 'Wall',
#    'vertices': [{'vertex_x_coordinate': 0,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 4.572},
#     {'vertex_x_coordinate': 0,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 0},
#     {'vertex_x_coordinate': 0,
#      'vertex_y_coordinate': 0,
#      'vertex_z_coordinate': 0},
#     {'vertex_x_coordinate': 0,
#      'vertex_y_coordinate': 0,
#      'vertex_z_coordinate': 4.572}],
#    'view_factor_to_ground': 0.5,
#    'wind_exposure': 'WindExposed',
#    'zone_name': 'ZONE ONE'}},
#  'Construction': {'FLOOR': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 2,
#    'idf_order': 16,
#    'outside_layer': 'C5 - 4 IN HW CONCRETE'},
#   'R13WALL': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 2,
#    'idf_order': 15,
#    'outside_layer': 'R13LAYER'},
#   'ROOF31': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 2,
#    'idf_order': 17,
#    'outside_layer': 'R31LAYER'}},
#  'Exterior:Lights': {'ExtLights': {'control_option': 'AstronomicalClock',
#    'design_level': 5250,
#    'end_use_subcategory': 'Grounds Lights',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 5,
#    'idf_order': 49,
#    'schedule_name': 'AlwaysOn'}},
#  'GlobalGeometryRules': {'GlobalGeometryRules 1': {'coordinate_system': 'World',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 20,
#    'starting_vertex_position': 'UpperLeftCorner',
#    'vertex_entry_direction': 'CounterClockWise'}},
#  'HeatBalanceAlgorithm': {'HeatBalanceAlgorithm 1': {'algorithm': 'ConductionTransferFunction',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 1,
#    'idf_order': 4}},
#  'Material': {'C5 - 4 IN HW CONCRETE': {'conductivity': 1.729577,
#    'density': 2242.585,
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 9,
#    'idf_order': 14,
#    'roughness': 'MediumRough',
#    'solar_absorptance': 0.65,
#    'specific_heat': 836.8,
#    'thermal_absorptance': 0.9,
#    'thickness': 0.1014984,
#    'visible_absorptance': 0.65}},
#  'Material:NoMass': {'R13LAYER': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 6,
#    'idf_order': 12,
#    'roughness': 'Rough',
#    'solar_absorptance': 0.75,
#    'thermal_absorptance': 0.9,
#    'thermal_resistance': 2.290965,
#    'visible_absorptance': 0.75},
#   'R31LAYER': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 6,
#    'idf_order': 13,
#    'roughness': 'Rough',
#    'solar_absorptance': 0.75,
#    'thermal_absorptance': 0.9,
#    'thermal_resistance': 5.456,
#    'visible_absorptance': 0.75}},
#  'OtherEquipment': {'Test 352 minus': {'design_level': -352,
#    'design_level_calculation_method': 'EquipmentLevel',
#    'fraction_latent': 0,
#    'fraction_lost': 0,
#    'fraction_radiant': 0,
#    'fuel_type': 'None',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 11,
#    'idf_order': 52,
#    'schedule_name': 'AlwaysOn',
#    'zone_or_zonelist_name': 'ZONE ONE'},
#   'Test 352a': {'design_level': 352,
#    'design_level_calculation_method': 'EquipmentLevel',
#    'fraction_latent': 0,
#    'fraction_lost': 0,
#    'fraction_radiant': 0,
#    'fuel_type': 'None',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 11,
#    'idf_order': 51,
#    'schedule_name': 'AlwaysOn',
#    'zone_or_zonelist_name': 'ZONE ONE'}},
#  'Output:Constructions': {'Output:Constructions 1': {'details_type_1': 'Constructions',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 1,
#    'idf_order': 43}},
#  'Output:Meter:MeterFileOnly': {'Output:Meter:MeterFileOnly 1': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 2,
#    'idf_order': 44,
#    'key_name': 'ExteriorLights:Electricity',
#    'reporting_frequency': 'Hourly'},
#   'Output:Meter:MeterFileOnly 2': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 2,
#    'idf_order': 45,
#    'key_name': 'EnergyTransfer:Building',
#    'reporting_frequency': 'Hourly'},
#   'Output:Meter:MeterFileOnly 3': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 2,
#    'idf_order': 46,
#    'key_name': 'EnergyTransfer:Facility',
#    'reporting_frequency': 'Hourly'}},
#  'Output:Surfaces:Drawing': {'Output:Surfaces:Drawing 1': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 1,
#    'idf_order': 42,
#    'report_type': 'DXF:WireFrame'}},
#  'Output:Table:SummaryReports': {'Output:Table:SummaryReports 1': {'idf_max_extensible_fields': 1,
#    'idf_max_fields': 1,
#    'idf_order': 48,
#    'reports': [{'report_name': 'AllSummary'}]}},
#  'Output:Variable': {'Output:Variable 1': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 27,
#    'key_value': '*',
#    'reporting_frequency': 'Hourly',
#    'variable_name': 'Site Outdoor Air Drybulb Temperature'},
#   'Output:Variable 2': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 28,
#    'key_value': '*',
#    'reporting_frequency': 'Daily',
#    'variable_name': 'Site Daylight Saving Time Status'},
#   'Output:Variable 3': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 29,
#    'key_value': '*',
#    'reporting_frequency': 'Daily',
#    'variable_name': 'Site Day Type Index'},
#   'Output:Variable 4': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 30,
#    'key_value': '*',
#    'reporting_frequency': 'Hourly',
#    'variable_name': 'Zone Mean Air Temperature'},
#   'Output:Variable 5': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 31,
#    'key_value': '*',
#    'reporting_frequency': 'Hourly',
#    'variable_name': 'Zone Total Internal Latent Gain Energy'},
#   'Output:Variable 6': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 32,
#    'key_value': '*',
#    'reporting_frequency': 'Hourly',
#    'variable_name': 'Zone Mean Radiant Temperature'},
#   'Output:Variable 7': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 33,
#    'key_value': '*',
#    'reporting_frequency': 'Hourly',
#    'variable_name': 'Zone Air Heat Balance Surface Convection Rate'},
#   'Output:Variable 8': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 34,
#    'key_value': '*',
#    'reporting_frequency': 'Hourly',
#    'variable_name': 'Zone Air Heat Balance Air Energy Storage Rate'},
#   'Output:Variable 9': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 35,
#    'key_value': '*',
#    'reporting_frequency': 'Daily',
#    'variable_name': 'Surface Inside Face Temperature'},
#   'Output:Variable 10': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 36,
#    'key_value': '*',
#    'reporting_frequency': 'Daily',
#    'variable_name': 'Surface Outside Face Temperature'},
#   'Output:Variable 11': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 37,
#    'key_value': '*',
#    'reporting_frequency': 'Daily',
#    'variable_name': 'Surface Inside Face Convection Heat Transfer Coefficient'},
#   'Output:Variable 12': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 38,
#    'key_value': '*',
#    'reporting_frequency': 'Daily',
#    'variable_name': 'Surface Outside Face Convection Heat Transfer Coefficient'},
#   'Output:Variable 13': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 39,
#    'key_value': '*',
#    'reporting_frequency': 'Monthly',
#    'variable_name': 'Other Equipment Total Heating Energy'},
#   'Output:Variable 14': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 40,
#    'key_value': '*',
#    'reporting_frequency': 'Monthly',
#    'variable_name': 'Zone Other Equipment Total Heating Energy'}},
#  'Output:VariableDictionary': {'Output:VariableDictionary 1': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 1,
#    'idf_order': 41,
#    'key_field': 'IDF'}},
#  'OutputControl:Table:Style': {'OutputControl:Table:Style 1': {'column_separator': 'All',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 1,
#    'idf_order': 47}},
#  'RunPeriod': {'': {'apply_weekend_holiday_rule': 'No',
#    'begin_day_of_month': 1,
#    'begin_month': 1,
#    'day_of_week_for_start_day': 'Tuesday',
#    'end_day_of_month': 31,
#    'end_month': 12,
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 11,
#    'idf_order': 8,
#    'use_weather_file_daylight_saving_period': 'Yes',
#    'use_weather_file_holidays_and_special_days': 'Yes',
#    'use_weather_file_rain_indicators': 'Yes',
#    'use_weather_file_snow_indicators': 'Yes'}},
#  'Schedule:Constant': {'AlwaysOn': {'hourly_value': 1.0,
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 3,
#    'idf_order': 53,
#    'schedule_type_limits_name': 'On/Off'}},
#  'ScheduleTypeLimits': {'Fraction': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 4,
#    'idf_order': 19,
#    'lower_limit_value': 0.0,
#    'numeric_type': 'Continuous',
#    'upper_limit_value': 1.0},
#   'On/Off': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 4,
#    'idf_order': 50,
#    'lower_limit_value': 0,
#    'numeric_type': 'Discrete',
#    'upper_limit_value': 1}},
#  'SimulationControl': {'SimulationControl 1': {'do_plant_sizing_calculation': 'No',
#    'do_system_sizing_calculation': 'No',
#    'do_zone_sizing_calculation': 'No',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 5,
#    'idf_order': 7,
#    'run_simulation_for_sizing_periods': 'Yes',
#    'run_simulation_for_weather_file_run_periods': 'Yes'}},
#  'Site:Location': {'Denver Centennial  Golden   N_CO_USA Design_Conditions': {'elevation': 1829.0,
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 5,
#    'idf_order': 9,
#    'latitude': 39.74,
#    'longitude': -105.18,
#    'time_zone': -7.0}},
#  'SizingPeriod:DesignDay': {'Denver Centennial  Golden   N Ann Clg 1% Condns DB=>MWB': {'barometric_pressure': 81198.0,
#    'daily_dry_bulb_temperature_range': 15.2,
#    'day_of_month': 21,
#    'day_type': 'SummerDesignDay',
#    'daylight_saving_time_indicator': 'No',
#    'humidity_condition_type': 'WetBulb',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 26,
#    'idf_order': 11,
#    'maximum_dry_bulb_temperature': 32,
#    'month': 7,
#    'rain_indicator': 'No',
#    'sky_clearness': 1.0,
#    'snow_indicator': 'No',
#    'solar_model_indicator': 'ASHRAEClearSky',
#    'wetbulb_or_dewpoint_at_maximum_dry_bulb': 15.5,
#    'wind_direction': 0,
#    'wind_speed': 4.9},
#   'Denver Centennial  Golden   N Ann Htg 99% Condns DB': {'barometric_pressure': 81198.0,
#    'daily_dry_bulb_temperature_range': 0.0,
#    'day_of_month': 21,
#    'day_type': 'WinterDesignDay',
#    'daylight_saving_time_indicator': 'No',
#    'humidity_condition_type': 'WetBulb',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 26,
#    'idf_order': 10,
#    'maximum_dry_bulb_temperature': -15.5,
#    'month': 12,
#    'rain_indicator': 'No',
#    'sky_clearness': 0.0,
#    'snow_indicator': 'No',
#    'solar_model_indicator': 'ASHRAEClearSky',
#    'wetbulb_or_dewpoint_at_maximum_dry_bulb': -15.5,
#    'wind_direction': 340,
#    'wind_speed': 3}},
#  'SurfaceConvectionAlgorithm:Inside': {'SurfaceConvectionAlgorithm:Inside 1': {'algorithm': 'TARP',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 1,
#    'idf_order': 5}},
#  'SurfaceConvectionAlgorithm:Outside': {'SurfaceConvectionAlgorithm:Outside 1': {'algorithm': 'DOE-2',
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 1,
#    'idf_order': 6}},
#  'Timestep': {'Timestep 1': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 1,
#    'idf_order': 2,
#    'number_of_timesteps_per_hour': 4}},
#  'Version': {'Version 1': {'idf_max_extensible_fields': 0,
#    'idf_max_fields': 1,
#    'idf_order': 1,
#    'version_identifier': '8.9'}},
#  'Zone': {'ZONE ONE': {'ceiling_height': 'Autocalculate',
#    'direction_of_relative_north': 0,
#    'idf_max_extensible_fields': 0,
#    'idf_max_fields': 9,
#    'idf_order': 18,
#    'multiplier': 1,
#    'type': 1,
#    'volume': 'Autocalculate',
#    'x_origin': 0,
#    'y_origin': 0,
#    'z_origin': 0}}}

# %%
data['Building']
# Out:
# {'Simple One Zone (Wireframe DXF)': {'idf_max_extensible_fields': 0,
#   'idf_max_fields': 8,
#   'idf_order': 3,
#   'loads_convergence_tolerance_value': 0.04,
#   'maximum_number_of_warmup_days': 30,
#   'minimum_number_of_warmup_days': 6,
#   'north_axis': 0,
#   'solar_distribution': 'MinimalShadowing',
#   'temperature_convergence_tolerance_value': 0.004,
#   'terrain': 'Suburbs'}}

# %% [markdown]
# ### Count of idf objects

# %%
{k:len(v) for k,v in data.items() if len(v)>0}
# Out:
# {'Building': 1,
#  'BuildingSurface:Detailed': 6,
#  'Construction': 3,
#  'Exterior:Lights': 1,
#  'GlobalGeometryRules': 1,
#  'HeatBalanceAlgorithm': 1,
#  'Material': 1,
#  'Material:NoMass': 2,
#  'OtherEquipment': 2,
#  'Output:Constructions': 1,
#  'Output:Meter:MeterFileOnly': 3,
#  'Output:Surfaces:Drawing': 1,
#  'Output:Table:SummaryReports': 1,
#  'Output:Variable': 14,
#  'Output:VariableDictionary': 1,
#  'OutputControl:Table:Style': 1,
#  'RunPeriod': 1,
#  'Schedule:Constant': 1,
#  'ScheduleTypeLimits': 2,
#  'SimulationControl': 1,
#  'Site:Location': 1,
#  'SizingPeriod:DesignDay': 2,
#  'SurfaceConvectionAlgorithm:Inside': 1,
#  'SurfaceConvectionAlgorithm:Outside': 1,
#  'Timestep': 1,
#  'Version': 1,
#  'Zone': 1}
